# %% [markdown]
# ## Display Features

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
import warnings

from xml.etree.ElementTree import fromstring, ElementTree
from sklearn.metrics import classification_report

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

# %% [markdown]
# # Matches

# %%
matches = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches6.csv",
    index_col=0,
)

# %%
matches.head()
# Out:
#    Date  LeagueID              LeagueName  MatchID  HomeTeamID  AwayTeamID  \
# 0  2010         1  Belgium Jupiler League   665626        8635        8342
# 1  2010         1  Belgium Jupiler League   838635        8635        8342
# 2  2010         1  Belgium Jupiler League   838544        9986        8342
# 3  2010         1  Belgium Jupiler League   838714        8203        8342
# 4  2010         1  Belgium Jupiler League   665737        9997        8342
#
#    HomeGoal  AwayGoal  TotalGoals  Result  HomePlayer1  HomePlayer2  \
# 0         3         2           5       1         72.0         72.0
# 1         2         2           4       0         72.0         74.0
# 2         0         5           5      -1         55.0         63.0
# 3         0         1           1      -1         70.0         64.0
# 4         1         1           2       0         68.0         70.0
#
#    HomePlayer3  HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  \
# 0         72.0         74.0         70.0         71.0         75.0
# 1         70.0         71.0         60.0         72.0         69.0
# 2         62.0         64.0         64.0         63.0         66.0
# 3         63.0         66.0         65.0         66.0         65.0
# 4         65.0         64.0         65.0         66.0         63.0
#
#    HomePlayer8  HomePlayer9  HomePlayer10  HomePlayer11  AwayPlayer1  \
# 0         68.0         72.0          78.0          74.0         72.0
# 1         68.0         68.0          72.0          74.0         65.0
# 2         62.0         61.0          72.0          63.0         65.0
# 3         66.0         63.0          66.0          66.0         72.0
# 4         67.0         64.0          62.0          73.0         72.0
#
#    AwayPlayer2  AwayPlayer3  AwayPlayer4  AwayPlayer5  AwayPlayer6  \
# 0         72.0         68.0         72.0         68.0         69.0
# 1         72.0         68.0         67.0         72.0         68.0
# 2         72.0         68.0         70.0         72.0         72.0
# 3         72.0         68.0         67.0         70.0         68.0
# 4         72.0         68.0         70.0         70.0         68.0
#
#    AwayPlayer7  AwayPlayer8  AwayPlayer9  AwayPlayer10  AwayPlayer11  \
# 0         70.0         70.0         70.0          72.0          70.0
# 1         70.0         72.0         72.0          72.0          70.0
# 2         64.0         72.0         72.0          70.0          72.0
# 3         72.0         70.0         72.0          72.0          69.0
# 4         69.0         70.0         72.0          71.0          69.0
#
#    HomeShoton  AwayShoton  HomeShotoff  AwayShotoff  HomeFoulCommit  \
# 0         4.0         3.0          4.0          3.0             7.0
# 1         4.0         3.0          4.0          3.0             7.0
# 2         4.0         3.0          4.0          3.0             7.0
# 3         4.0         3.0          4.0          3.0             7.0
# 4         4.0         3.0          4.0          3.0             7.0
#
#    AwayFoulCommit  HomeCard  AwayCard  HomeCross  AwayCross  HomeCorner  \
# 0             7.0       2.0       2.0       11.0        8.0         3.0
# 1             7.0       2.0       2.0       11.0        8.0         3.0
# 2             7.0       2.0       2.0       11.0        8.0         3.0
# 3             7.0       2.0       2.0       11.0        8.0         3.0
# 4             7.0       2.0       2.0       11.0        8.0         3.0
#
#    AwayCorner    HomeTeamLongName HomeTeamShortName  HomeBuildUpPlaySpeed  \
# 0         3.0      RSC Anderlecht               AND                    50
# 1         3.0      RSC Anderlecht               AND                    50
# 2         3.0  Sporting Charleroi               CHA                    40
# 3         3.0         KV Mechelen               MEC                    65
# 4         3.0   Sint-Truidense VV               STT                    50
#
#    HomeBuildUpPlayPassing  HomeChanceCreationPassing  \
# 0                      35                         70
# 1                      35                         70
# 2                      50                         45
# 3                      60                         50
# 4                      50                         50
#
#    HomeChanceCreationCrossing  HomeChanceCreationShooting  \
# 0                          50                          60
# 1                          50                          60
# 2                          43                          60
# 3                          40                          50
# 4                          50                          50
#
#    HomeDefencePressure  HomeDefenceAggression  HomeDefenceTeamWidth  \
# 0                   70                     50                    70
# 1                   70                     50                    70
# 2                   70                     70                    70
# 3                   60                     70                    60
# 4                   50                     50                    50
#
#   AwayTeamLongName AwayTeamShortName  AwayBuildUpPlaySpeed  \
# 0   Club Brugge KV               CLB                    35
# 1   Club Brugge KV               CLB                    35
# 2   Club Brugge KV               CLB                    35
# 3   Club Brugge KV               CLB                    35
# 4   Club Brugge KV               CLB                    35
#
#    AwayBuildUpPlayPassing  AwayChanceCreationPassing  \
# 0                      40                         45
# 1                      40                         45
# 2                      40                         45
# 3                      40                         45
# 4                      40                         45
#
#    AwayChanceCreationCrossing  AwayChanceCreationShooting  \
# 0                          50                          45
# 1                          50                          45
# 2                          50                          45
# 3                          50                          45
# 4                          50                          45
#
#    AwayDefencePressure  AwayDefenceAggression  AwayDefenceTeamWidth
# 0                   60                     70                    70
# 1                   60                     70                    70
# 2                   60                     70                    70
# 3                   60                     70                    70
# 4                   60                     70                    70

# %%
matches.shape
# Out:
# (18243, 64)

# %%
sample = matches[['HomePlayer1', 'AwayPlayer1','Result']]

# %%
sample.head()
# Out:
#    HomePlayer1  AwayPlayer1  Result
# 0         72.0         72.0       1
# 1         72.0         65.0       0
# 2         55.0         65.0      -1
# 3         70.0         72.0      -1
# 4         68.0         72.0       0

# %%
from sklearn.linear_model import LogisticRegression

X = sample[['HomePlayer1', 'AwayPlayer1']]
y = sample['Result']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
log_model = LogisticRegression()

# %%
log_model.fit(scaled_X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predict = log_model.predict(X_test)
print(classification_report(y_test, y_predict))
# Out:
# C:\Users\Space\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#           -1       0.41      0.47      0.44       538
#            0       0.00      0.00      0.00       458
#            1       0.52      0.76      0.62       829
#
#     accuracy                           0.48      1825
#    macro avg       0.31      0.41      0.35      1825
# weighted avg       0.36      0.48      0.41      1825
# C:\Users\Space\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Space\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Space\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
