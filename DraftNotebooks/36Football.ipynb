# %% [markdown]
# ## Display Features

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings

from xml.etree.ElementTree import fromstring, ElementTree
import xml.etree.ElementTree as ET

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %% [markdown]
# # Matches

# %%
matches = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches8.csv",
    index_col=0,
)

# %%
matches.head()
# Out:
#    Date  LeagueID              LeagueName  MatchID  HomeTeamID  \
# 0  2010         1  Belgium Jupiler League   665626        8635
# 1  2010         1  Belgium Jupiler League   838635        8635
# 2  2010         1  Belgium Jupiler League   838544        9986
# 3  2010         1  Belgium Jupiler League   838714        8203
# 4  2010         1  Belgium Jupiler League   665737        9997
#
#      HomeTeamLongName HomeTeamShortName  AwayTeamID AwayTeamLongName  \
# 0      RSC Anderlecht               AND        8342   Club Brugge KV
# 1      RSC Anderlecht               AND        8342   Club Brugge KV
# 2  Sporting Charleroi               CHA        8342   Club Brugge KV
# 3         KV Mechelen               MEC        8342   Club Brugge KV
# 4   Sint-Truidense VV               STT        8342   Club Brugge KV
#
#   AwayTeamShortName  HomeGoal  AwayGoal  TotalGoals  HomePlayer1  HomePlayer2  \
# 0               CLB         3         2           5     72.00000     72.00000
# 1               CLB         2         2           4     72.00000     74.00000
# 2               CLB         0         5           5     55.00000     63.00000
# 3               CLB         0         1           1     70.00000     64.00000
# 4               CLB         1         1           2     68.00000     70.00000
#
#    HomePlayer3  HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  \
# 0     72.00000     74.00000     70.00000     71.00000     75.00000
# 1     70.00000     71.00000     60.00000     72.00000     69.00000
# 2     62.00000     64.00000     64.00000     63.00000     66.00000
# 3     63.00000     66.00000     65.00000     66.00000     65.00000
# 4     65.00000     64.00000     65.00000     66.00000     63.00000
#
#    HomePlayer8  HomePlayer9  HomePlayer10  HomePlayer11  AwayPlayer1  \
# 0     68.00000     72.00000      78.00000      74.00000     72.00000
# 1     68.00000     68.00000      72.00000      74.00000     65.00000
# 2     62.00000     61.00000      72.00000      63.00000     65.00000
# 3     66.00000     63.00000      66.00000      66.00000     72.00000
# 4     67.00000     64.00000      62.00000      73.00000     72.00000
#
#    AwayPlayer2  AwayPlayer3  AwayPlayer4  AwayPlayer5  AwayPlayer6  \
# 0     72.00000     68.00000     72.00000     68.00000     69.00000
# 1     72.00000     68.00000     67.00000     72.00000     68.00000
# 2     72.00000     68.00000     70.00000     72.00000     72.00000
# 3     72.00000     68.00000     67.00000     70.00000     68.00000
# 4     72.00000     68.00000     70.00000     70.00000     68.00000
#
#    AwayPlayer7  AwayPlayer8  AwayPlayer9  AwayPlayer10  AwayPlayer11  \
# 0     70.00000     70.00000     70.00000      72.00000      70.00000
# 1     70.00000     72.00000     72.00000      72.00000      70.00000
# 2     64.00000     72.00000     72.00000      70.00000      72.00000
# 3     72.00000     70.00000     72.00000      72.00000      69.00000
# 4     69.00000     70.00000     72.00000      71.00000      69.00000
#
#    HomeShoton  AwayShoton  HomeShotoff  AwayShotoff  HomeFoulCommit  \
# 0     3.00000     3.00000      4.00000      3.00000         7.00000
# 1     3.00000     3.00000      4.00000      3.00000         7.00000
# 2     3.00000     3.00000      4.00000      3.00000         7.00000
# 3     3.00000     3.00000      4.00000      3.00000         7.00000
# 4     3.00000     3.00000      4.00000      3.00000         7.00000
#
#    AwayFoulCommit  HomeCard  AwayCard  HomeCross  AwayCross  HomeCorner  \
# 0         7.00000   2.00000   2.00000   11.00000    8.00000     3.00000
# 1         7.00000   2.00000   2.00000   11.00000    8.00000     3.00000
# 2         7.00000   2.00000   2.00000   11.00000    8.00000     3.00000
# 3         7.00000   2.00000   2.00000   11.00000    8.00000     3.00000
# 4         7.00000   2.00000   2.00000   11.00000    8.00000     3.00000
#
#    AwayCorner  HomeBuildUpPlaySpeed  HomeBuildUpPlayPassing  \
# 0     3.00000                    50                      35
# 1     3.00000                    50                      35
# 2     3.00000                    40                      50
# 3     3.00000                    65                      60
# 4     3.00000                    50                      50
#
#    HomeChanceCreationPassing  HomeChanceCreationCrossing  \
# 0                         70                          50
# 1                         70                          50
# 2                         45                          43
# 3                         50                          40
# 4                         50                          50
#
#    HomeChanceCreationShooting  HomeDefencePressure  HomeDefenceAggression  \
# 0                          60                   70                     50
# 1                          60                   70                     50
# 2                          60                   70                     70
# 3                          50                   60                     70
# 4                          50                   50                     50
#
#    HomeDefenceTeamWidth  AwayBuildUpPlaySpeed  AwayBuildUpPlayPassing  \
# 0                    70                    35                      40
# 1                    70                    35                      40
# 2                    70                    35                      40
# 3                    60                    35                      40
# 4                    50                    35                      40
#
#    AwayChanceCreationPassing  AwayChanceCreationCrossing  \
# 0                         45                          50
# 1                         45                          50
# 2                         45                          50
# 3                         45                          50
# 4                         45                          50
#
#    AwayChanceCreationShooting  AwayDefencePressure  AwayDefenceAggression  \
# 0                          45                   60                     70
# 1                          45                   60                     70
# 2                          45                   60                     70
# 3                          45                   60                     70
# 4                          45                   60                     70
#
#    AwayDefenceTeamWidth  Result
# 0                    70       1
# 1                    70       0
# 2                    70      -1
# 3                    70      -1
# 4                    70       0

# %% [markdown]
# # Logistic Regression

# %%
X = matches.drop(
    [
        "Date",
        "LeagueID",
        "LeagueName",
        "MatchID",
        "HomeTeamID",
# 2    8.00000     3.00000     3.00000                    40
# 3    8.00000     3.00000     3.00000                    65
# 4    8.00000     3.00000     3.00000                    50
#
#    HomeBuildUpPlayPassing  HomeChanceCreationPassing  \
# 0                      35                         70
# 1                      35                         70
# 2                      50                         45
# 3                      60                         50
# 4                      50                         50
#
#    HomeChanceCreationCrossing  HomeChanceCreationShooting  \
# 0                          50                          60
# 1                          50                          60
# 2                          43                          60
# 3                          40                          50
# 4                          50                          50
#
#    HomeDefencePressure  HomeDefenceAggression  HomeDefenceTeamWidth  \
# 0                   70                     50                    70
# 1                   70                     50                    70
# 2                   70                     70                    70
# 3                   60                     70                    60
# 4                   50                     50                    50
#
#    AwayBuildUpPlaySpeed  AwayBuildUpPlayPassing  AwayChanceCreationPassing  \
# 0                    35                      40                         45
# 1                    35                      40                         45
# 2                    35                      40                         45
# 3                    35                      40                         45
# 4                    35                      40                         45
#
#    AwayChanceCreationCrossing  AwayChanceCreationShooting  \
# 0                          50                          45
# 1                          50                          45
# 2                          50                          45
# 3                          50                          45
# 4                          50                          45
#
#    AwayDefencePressure  AwayDefenceAggression  AwayDefenceTeamWidth
# 0                   60                     70                    70
# 1                   60                     70                    70
# 2                   60                     70                    70
# 3                   60                     70                    70
# 4                   60                     70                    70

# %%
y = matches['Result']

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2   -1
# 3   -1
# 4    0
# Name: Result, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.2, random_state=101)

# %%
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression(solver="liblinear", random_state=None)
log_model.fit(X_train, y_train)
y_predict = log_model.predict(X_test)

# %%
log_model.coef_
# Out:
# array([[-2.07329998e-03, -1.74063563e-02, -2.76095679e-02,
#         -2.18338345e-02, -1.47088089e-02, -1.86419022e-02,
#         -2.04589801e-02, -2.52695470e-02, -1.26070133e-02,
#         -1.41657944e-02, -1.41014218e-02,  8.68425628e-03,
#          5.89993609e-03,  1.62815834e-02,  2.08043741e-02,
#          1.89009811e-02,  1.80579665e-02,  2.15860366e-02,
#          1.61993555e-02,  1.54075727e-02,  2.04508906e-02,
#          1.62964634e-02, -1.20687733e-02,  3.06970982e-02,
#          3.05124660e-03,  1.93827393e-02, -1.14472285e-02,
#          5.32823473e-03,  1.73578704e-01, -1.32955712e-01,
#          6.70004740e-02, -9.05210825e-02, -3.67371514e-02,
#          4.84811088e-02,  1.47736585e-03, -7.43568833e-04,
#          7.04996644e-04,  6.14614273e-04, -2.63518221e-03,
#         -5.57465927e-04, -7.04007008e-05, -3.56413331e-03,
#          2.88579427e-05, -2.33963235e-03,  5.15033111e-06,
#          2.21319470e-03, -4.69983437e-03,  1.79875681e-03,
#          1.74883766e-03,  2.12556049e-03],
#        [ 4.75035985e-03, -7.26829334e-04,  9.53942982e-03,
#         -3.45863000e-03, -1.27007199e-03, -7.66872416e-03,
#          6.20577683e-03, -1.02950099e-02, -7.31943049e-03,
#         -8.16296127e-03, -1.74471930e-02,  4.96973621e-03,
#          4.81413964e-04,  1.26942053e-02,  3.94644887e-03,
#          5.80991175e-03,  1.73384179e-03, -1.21254103e-03,
#          6.39789985e-03, -1.68373386e-03, -4.09787807e-03,
#         -6.95898598e-03, -1.01478197e-04, -1.23133425e-02,
#         -1.77368800e-02,  4.23947199e-03, -1.23863531e-02,
#          4.85621494e-03,  4.50774137e-02,  5.76195172e-02,
#          1.39793988e-02, -3.62913921e-03,  6.69307792e-03,
#          2.15796932e-04,  4.37306412e-03, -7.00387709e-05,
#          7.96294099e-04, -3.28975369e-03,  4.41318411e-04,
#         -6.08642365e-03,  1.01358892e-03,  4.59018400e-03,
#          9.94177933e-04,  4.53680640e-04, -5.53997420e-03,
#          1.96537375e-03, -9.16314426e-04,  3.69955577e-04,
#         -1.74557701e-03, -3.46155749e-03],
#        [-2.75540119e-03,  1.38909553e-02,  1.48872078e-02,
#          2.06907979e-02,  1.21173960e-02,  2.22274425e-02,
#          1.01161660e-02,  2.83242575e-02,  1.64020671e-02,
#          1.58446201e-02,  2.63007016e-02, -1.20292540e-02,
#         -6.02999539e-03, -2.39987185e-02, -2.14826469e-02,
#         -2.15075371e-02, -1.73734182e-02, -1.81494245e-02,
#         -2.05069150e-02, -1.29278604e-02, -1.61121116e-02,
#         -7.60244974e-03,  1.05871730e-02, -1.96244616e-02,
#          7.83687795e-03, -2.12261985e-02,  2.06062444e-02,
#         -6.81140754e-03, -1.83581979e-01,  7.02820940e-02,
#         -6.90399424e-02,  7.96928523e-02,  2.75460478e-02,
#         -4.35413178e-02, -4.78997564e-03,  6.65963904e-05,
#         -2.19931776e-03,  2.23331558e-03,  6.15770721e-04,
#          5.47003939e-03, -5.64146227e-04, -1.23870995e-03,
#         -7.58113594e-04,  9.68473869e-04,  4.71757215e-03,
#         -4.34578969e-03,  3.40820683e-03, -2.63336582e-03,
#         -4.30232182e-05,  6.14657424e-04]])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,plot_confusion_matrix

# %%
y_pred = log_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.5272677445875582

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 545,   10,  495],
#        [ 294,    4,  635],
#        [ 280,   11, 1375]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.49      0.52      0.50      1050
#            0       0.16      0.00      0.01       933
#            1       0.55      0.83      0.66      1666
#
#     accuracy                           0.53      3649
#    macro avg       0.40      0.45      0.39      3649
# weighted avg       0.43      0.53      0.45      3649
