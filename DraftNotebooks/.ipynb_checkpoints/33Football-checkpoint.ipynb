# %% [markdown]
# ## Display Features

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings

from xml.etree.ElementTree import fromstring, ElementTree
import xml.etree.ElementTree as ET

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

# %% [markdown]
# # Matches

# %%
matches = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches8.csv",
    index_col=0,
)

# %%
matches.head()
# Out:
#    Date  LeagueID              LeagueName  MatchID  HomeTeamID  \
# 0  2010         1  Belgium Jupiler League   665626        8635
# 1  2010         1  Belgium Jupiler League   838635        8635
# 2  2010         1  Belgium Jupiler League   838544        9986
# 3  2010         1  Belgium Jupiler League   838714        8203
# 4  2010         1  Belgium Jupiler League   665737        9997
#
#      HomeTeamLongName HomeTeamShortName  AwayTeamID AwayTeamLongName  \
# 0      RSC Anderlecht               AND        8342   Club Brugge KV
# 1      RSC Anderlecht               AND        8342   Club Brugge KV
# 2  Sporting Charleroi               CHA        8342   Club Brugge KV
# 3         KV Mechelen               MEC        8342   Club Brugge KV
# 4   Sint-Truidense VV               STT        8342   Club Brugge KV
#
#   AwayTeamShortName  HomeGoal  AwayGoal  TotalGoals  HomePlayer1  HomePlayer2  \
# 0               CLB         3         2           5         72.0         72.0
# ...

# %%
X = matches.loc [:, 'HomeShoton': 'AwayDefenceTeamWidth']
y = matches['Result']

# %%
X.head()
# Out:
#    HomeShoton  AwayShoton  HomeShotoff  AwayShotoff  HomeFoulCommit  \
# 0         3.0         3.0          4.0          3.0             7.0
# 1         3.0         3.0          4.0          3.0             7.0
# 2         3.0         3.0          4.0          3.0             7.0
# 3         3.0         3.0          4.0          3.0             7.0
# 4         3.0         3.0          4.0          3.0             7.0
#
#    AwayFoulCommit  HomeCard  AwayCard  HomeCross  AwayCross  HomeCorner  \
# 0             7.0       2.0       2.0       11.0        8.0         3.0
# 1             7.0       2.0       2.0       11.0        8.0         3.0
# 2             7.0       2.0       2.0       11.0        8.0         3.0
# 3             7.0       2.0       2.0       11.0        8.0         3.0
# 4             7.0       2.0       2.0       11.0        8.0         3.0
#
#    AwayCorner  HomeBuildUpPlaySpeed  HomeBuildUpPlayPassing  \
# ...

# %%
X.shape
# Out:
# (18243, 28)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_X = scaler.fit_transform(X)

# %%
model = LogisticRegression()
rfe = RFE(model)

# %%
X = scaled_X
y = y.values

# %%
X
# Out:
# array([[-0.0921916 ,  0.05339578,  0.09789246, ...,  1.30629246,
#          2.04122653,  1.85300823],
#        [-0.0921916 ,  0.05339578,  0.09789246, ...,  1.30629246,
#          2.04122653,  1.85300823],
#        [-0.0921916 ,  0.05339578,  0.09789246, ...,  1.30629246,
#          2.04122653,  1.85300823],
#        ...,
#        [-0.0921916 ,  0.05339578,  0.09789246, ..., -1.01364556,
#         -0.65662143, -0.55386495],
#        [-0.0921916 ,  0.05339578,  0.09789246, ..., -1.01364556,
#         -0.65662143, -0.55386495],
#        [-0.0921916 ,  0.05339578,  0.09789246, ..., -1.01364556,
#         -0.65662143, -0.55386495]])

# %%
y
# Out:
# array([ 1,  0, -1, ..., -1, -1,  1], dtype=int64)

# %%
fit = rfe.fit(X,y)

# %%
print(fit.n_features_)
# Out:
# 14

# %%
print(fit.support_)
# Out:
# [ True  True  True  True False False  True  True  True  True  True  True
#  False  True False False False  True False False False  True False False
#  False  True False False]

# %%
print(fit.ranking_)
# Out:
# [ 1  1  1  1 14 15  1  1  1  1  1  1 12  1  9  4  3  1  8 10  5  1  6  2
#  11  1  7 13]

# %%
#15: AwayFoulCommit (5)
#14: HomeFoulCommit (4)
#13: AwayDefenceTeamWidth (27)
#12: HomeBuildUpPlaySpeed (12)
#11: AwayChanceCreationShooting (24)
#10: HomeDefenceTeamWidth (19)
#09: HomeChanceCreationPassing (14)
#08: HomeDefenceAggression (18)
#07: AwayDefenceAggression (26)
#06: AwayChanceCreationPassing (22)
#05: AwayBuildUpPlaySpeed (20)
#04: HomeChanceCreationShooting (15)
#03: HomeDefencePressure (16)
#02: AwayChanceCreationCrossing (23)

# %%
list((X.columns.values))
# Out:
# ['HomeShoton',
#  'AwayShoton',
#  'HomeShotoff',
#  'AwayShotoff',
#  'HomeFoulCommit',
#  'AwayFoulCommit',
#  'HomeCard',
#  'AwayCard',
#  'HomeCross',
#  'AwayCross',
#  'HomeCorner',
#  'AwayCorner',
#  'HomeBuildUpPlaySpeed',
#  'HomeBuildUpPlayPassing',
#  'HomeChanceCreationPassing',
#  'HomeChanceCreationCrossing',
#  'HomeChanceCreationShooting',
#  'HomeDefencePressure',
#  'HomeDefenceAggression',
#  'HomeDefenceTeamWidth',
#  'AwayBuildUpPlaySpeed',
#  'AwayBuildUpPlayPassing',
#  'AwayChanceCreationPassing',
#  'AwayChanceCreationCrossing',
#  'AwayChanceCreationShooting',
#  'AwayDefencePressure',
#  'AwayDefenceAggression',
#  'AwayDefenceTeamWidth']
