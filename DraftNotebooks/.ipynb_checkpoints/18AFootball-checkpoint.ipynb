# %% [markdown]
# ## Display Features

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings

from xml.etree.ElementTree import fromstring, ElementTree
import xml.etree.ElementTree as ET

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

# %% [markdown]
# # Matches

# %%
matches = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches.csv",
    index_col=0,
)

# %%
matches.head()
# Out:
#    Date  LeagueID              LeagueName  MatchID  HomeTeamID  AwayTeamID  \
# 0  2010         1  Belgium Jupiler League   665626        8635        8342
# 1  2010         1  Belgium Jupiler League   838635        8635        8342
# 2  2010         1  Belgium Jupiler League   838544        9986        8342
# 3  2010         1  Belgium Jupiler League   838714        8203        8342
# 4  2010         1  Belgium Jupiler League   665737        9997        8342
#
#    HomeGoal  AwayGoal  TotalGoals  Result  HomePlayer1  HomePlayer2  \
# 0         3         2           5       1         72.0         72.5
# 1         2         2           4       0         72.0         74.0
# 2         0         5           5      -1         55.0         63.0
# 3         0         1           1      -1         69.5         63.5
# 4         1         1           2       0         68.5          NaN
#
#    HomePlayer3  HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  \
# 0         72.0         74.0         70.5         71.0         75.0
# 1         70.5         71.0         60.0         72.5         69.0
# 2         62.0         64.0         64.5         63.0         66.0
# 3         63.0         66.0         65.0         66.0         65.0
# 4         65.0         64.0         65.0         66.0         63.0
#
#    HomePlayer8  HomePlayer9  HomePlayer10  HomePlayer11  AwayPlayer1  \
# 0         68.5         72.5          78.0          74.0         72.5
# 1         68.5         68.0          72.0          74.0         65.0
# 2         62.0         61.0           NaN          63.0         65.0
# 3         66.0         63.0          66.0          66.5         72.5
# 4         67.0         64.5          62.0           NaN         72.5
#
#    AwayPlayer2  AwayPlayer3  AwayPlayer4  AwayPlayer5  AwayPlayer6  \
# 0         72.0         68.5         71.5         67.5         69.0
# 1         72.0         68.0         67.0         72.0         67.5
# 2         72.0         67.5         70.0         72.0         72.5
# 3         72.0         68.0         67.0         70.0         67.5
# 4         72.0         68.5         69.5         70.0         67.5
#
#    AwayPlayer7  AwayPlayer8  AwayPlayer9  AwayPlayer10  AwayPlayer11  \
# 0         69.5         70.0         70.5          72.0          70.5
# 1         70.5         72.5         72.5          72.0          70.5
# 2         64.0         71.5         72.5          70.5          72.0
# 3         71.5         70.5         72.0          72.5          69.0
# 4         69.0         70.5         72.0          71.0          69.0
#
#    HomeShoton  AwayShoton  HomeShotoff  AwayShotoff  HomeFoulCommit  \
# 0         NaN         NaN          NaN          NaN             NaN
# 1         NaN         NaN          NaN          NaN             NaN
# 2         NaN         NaN          NaN          NaN             NaN
# 3         NaN         NaN          NaN          NaN             NaN
# 4         NaN         NaN          NaN          NaN             NaN
#
#    AwayFoulCommit  HomeCard  AwayCard  HomeCross  AwayCross  HomeCorner  \
# 0             NaN       NaN       NaN        NaN        NaN         NaN
# 1             NaN       NaN       NaN        NaN        NaN         NaN
# 2             NaN       NaN       NaN        NaN        NaN         NaN
# 3             NaN       NaN       NaN        NaN        NaN         NaN
# 4             NaN       NaN       NaN        NaN        NaN         NaN
#
#    AwayCorner  HomePossession  AwayPossession    HomeTeamLongName  \
# 0         NaN             NaN             NaN      RSC Anderlecht
# 1         NaN             NaN             NaN      RSC Anderlecht
# 2         NaN             NaN             NaN  Sporting Charleroi
# 3         NaN             NaN             NaN         KV Mechelen
# 4         NaN             NaN             NaN   Sint-Truidense VV
#
#   HomeTeamShortName  HomeBuildUpPlaySpeed  HomeBuildUpPlayPassing  \
# 0               AND                    50                      35
# 1               AND                    50                      35
# 2               CHA                    40                      50
# 3               MEC                    65                      60
# 4               STT                    50                      50
#
#    HomeChanceCreationPassing  HomeChanceCreationCrossing  \
# 0                         70                          50
# 1                         70                          50
# 2                         45                          43
# 3                         50                          40
# 4                         50                          50
#
#    HomeChanceCreationShooting  HomeDefencePressure  HomeDefenceAggression  \
# 0                          60                   70                     50
# 1                          60                   70                     50
# 2                          60                   70                     70
# 3                          50                   60                     70
# 4                          50                   50                     50
#
#    HomeDefenceTeamWidth AwayTeamLongName AwayTeamShortName  \
# 0                    70   Club Brugge KV               CLB
# 1                    70   Club Brugge KV               CLB
# 2                    70   Club Brugge KV               CLB
# 3                    60   Club Brugge KV               CLB
# 4                    50   Club Brugge KV               CLB
#
#    AwayBuildUpPlaySpeed  AwayBuildUpPlayPassing  AwayChanceCreationPassing  \
# 0                    35                      40                         45
# 1                    35                      40                         45
# 2                    35                      40                         45
# 3                    35                      40                         45
# 4                    35                      40                         45
#
#    AwayChanceCreationCrossing  AwayChanceCreationShooting  \
# 0                          50                          45
# 1                          50                          45
# 2                          50                          45
# 3                          50                          45
# 4                          50                          45
#
#    AwayDefencePressure  AwayDefenceAggression  AwayDefenceTeamWidth
# 0                   60                     70                    70
# 1                   60                     70                    70
# 2                   60                     70                    70
# 3                   60                     70                    70
# 4                   60                     70                    70

# %%
matches.shape
# Out:
# (18243, 66)

# %%
matches.describe()
# Out:
#                Date      LeagueID       MatchID     HomeTeamID     AwayTeamID  \
# count  18243.000000  18243.000000  1.824300e+04   18243.000000   18243.000000
# mean    2012.491860  11644.669188  1.278929e+06    9642.721976    9628.273639
# std        1.721599   7518.931071  3.985441e+05   11064.968462   10844.519892
# min     2010.000000      1.000000  6.541530e+05    1601.000000    1601.000000
# 25%     2011.000000   4769.000000  8.884955e+05    8485.000000    8485.000000
# 50%     2012.000000  10257.000000  1.229197e+06    8697.000000    8697.000000
# 75%     2014.000000  17642.000000  1.709702e+06    9910.000000    9910.000000
# max     2015.000000  24558.000000  2.118418e+06  274581.000000  274581.000000
#
#            HomeGoal      AwayGoal    TotalGoals        Result   HomePlayer1  \
# count  18243.000000  18243.000000  18243.000000  18243.000000  17832.000000
# mean       1.549307      1.160719      2.710026      0.172505     72.914401
# std        1.300873      1.142005      1.676829      0.846519      6.892015
# min        0.000000      0.000000      0.000000     -1.000000     46.000000
# 25%        1.000000      0.000000      2.000000     -1.000000     68.000000
# 50%        1.000000      1.000000      3.000000      0.000000     74.000000
# 75%        2.000000      2.000000      4.000000      1.000000     78.000000
# max       10.000000      8.000000     12.000000      1.000000     90.000000
#
#         HomePlayer2   HomePlayer3   HomePlayer4   HomePlayer5   HomePlayer6  \
# count  17664.000000  17781.000000  17704.000000  17765.000000  17762.000000
# mean      69.925329     71.566859     71.504827     69.816282     71.422727
# std        6.237642      6.281149      6.411717      6.104431      6.473763
# min       46.500000     50.000000     46.500000     45.000000     44.000000
# 25%       65.500000     67.000000     67.000000     65.625000     67.000000
# 50%       70.500000     72.000000     72.000000     70.333333     72.000000
#        AwayPossession  HomeBuildUpPlaySpeed  HomeBuildUpPlayPassing  \
# count     6099.000000          18243.000000            18243.000000
# mean        48.296847             52.674944               47.862029
# std          9.579700             11.897339               11.144100
# min         18.875000             20.000000               20.000000
# 25%         42.000000             45.000000               39.000000
# 50%         48.000000             53.000000               49.000000
# 75%         54.500000             63.000000               55.000000
# max         80.500000             80.000000               80.000000
#
#        HomeChanceCreationPassing  HomeChanceCreationCrossing  \
# count               18243.000000                18243.000000
# mean                   52.477224                   54.076358
# std                    10.497135                   11.191892
# min                    21.000000                   20.000000
# 25%                    47.000000                   48.000000
# 50%                    52.000000                   53.000000
# 75%                    60.000000                   63.000000
# max                    80.000000                   80.000000
#
#        HomeChanceCreationShooting  HomeDefencePressure  HomeDefenceAggression  \
# count                18243.000000         18243.000000           18243.000000
# mean                    54.258675            46.482596              49.598038
# std                     10.599863            10.329139               9.998491
# min                     22.000000            23.000000              24.000000
# 25%                     49.000000            39.000000              44.000000
# 50%                     54.000000            46.000000              48.000000
# 75%                     63.000000            53.000000              56.000000
# max                     80.000000            72.000000              72.000000
#
#        HomeDefenceTeamWidth  AwayBuildUpPlaySpeed  AwayBuildUpPlayPassing  \
# count          18243.000000          18243.000000            18243.000000
# mean              52.275887             52.661788               47.866634
# std                9.552154             11.875227               11.134900
# min               29.000000             20.000000               20.000000
# 25%               48.000000             45.000000               39.000000
# 50%               52.000000             53.000000               49.000000
# 75%               59.000000             63.000000               55.000000
# max               73.000000             80.000000               80.000000
#
#        AwayChanceCreationPassing  AwayChanceCreationCrossing  \
# count               18243.000000                18243.000000
# mean                   52.505564                   54.066875
# std                    10.521294                   11.186052
# min                    21.000000                   20.000000
# 25%                    47.000000                   48.000000
# 50%                    52.000000                   53.000000
# 75%                    60.000000                   63.000000
# max                    80.000000                   80.000000
#
#        AwayChanceCreationShooting  AwayDefencePressure  AwayDefenceAggression  \
# count                18243.000000         18243.000000           18243.000000
# mean                    54.246177            46.486269              49.571452
# std                     10.609745            10.345388              10.008251
# min                     22.000000            23.000000              24.000000
# 25%                     48.000000            39.000000              44.000000
# 50%                     54.000000            46.000000              48.000000
# 75%                     63.000000            53.000000              56.000000
# max                     80.000000            72.000000              72.000000
#
#        AwayDefenceTeamWidth
# count          18243.000000
# mean              52.292715
# std                9.556229
# min               29.000000
# 25%               48.000000
# 50%               52.000000
# 75%               59.000000
# max               73.000000

# %%
sample = matches[['HomePlayer1', 'AwayPlayer1','Result']]

# %%
sample.head()
# Out:
#    HomePlayer1  AwayPlayer1  Result
# 0         72.0         72.5       1
# 1         72.0         65.0       0
# 2         55.0         65.0      -1
# 3         69.5         72.5      -1
# 4         68.5         72.5       0

# %%
sample = sample.dropna()

# %%
sample.shape
# Out:
# (17491, 3)

# %%
from sklearn.linear_model import LogisticRegression

X = sample[['HomePlayer1', 'AwayPlayer1']]
y = sample['Result']

X.dtypes
# Out:
# HomePlayer1    float64
# AwayPlayer1    float64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
log_model = LogisticRegression()

# %%
log_model.fit(scaled_X_train,y_train)
# Out:
# LogisticRegression()

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17491 entries, 0 to 18242
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   HomePlayer1  17491 non-null  float64
#  1   AwayPlayer1  17491 non-null  float64
#  2   Result       17491 non-null  int64
# dtypes: float64(2), int64(1)
# memory usage: 546.6 KB
