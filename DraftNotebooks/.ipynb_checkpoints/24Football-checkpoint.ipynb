# %% [markdown]
# ## Display Features

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings

from xml.etree.ElementTree import fromstring, ElementTree
import xml.etree.ElementTree as ET

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

# %% [markdown]
# # Matches

# %%
matches = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches.csv",
    index_col=0,
)

# %%
matches.head()
# Out:
#    Date  LeagueID              LeagueName  MatchID  HomeTeamID  AwayTeamID  \
# 0  2010         1  Belgium Jupiler League   665626        8635        8342
# 1  2010         1  Belgium Jupiler League   838635        8635        8342
# 2  2010         1  Belgium Jupiler League   838544        9986        8342
# 3  2010         1  Belgium Jupiler League   838714        8203        8342
# 4  2010         1  Belgium Jupiler League   665737        9997        8342
#
#    HomeGoal  AwayGoal  TotalGoals  Result  HomePlayer1  HomePlayer2  \
# 0         3         2           5       1         72.0         72.5
# 1         2         2           4       0         72.0         74.0
# 2         0         5           5      -1         55.0         63.0
# 3         0         1           1      -1         69.5         63.5
# 4         1         1           2       0         68.5          NaN
#
#    HomePlayer3  HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  \
# 0         72.0         74.0         70.5         71.0         75.0
# 1         70.5         71.0         60.0         72.5         69.0
# 2         62.0         64.0         64.5         63.0         66.0
# 3         63.0         66.0         65.0         66.0         65.0
# 4         65.0         64.0         65.0         66.0         63.0
#
#    HomePlayer8  HomePlayer9  HomePlayer10  HomePlayer11  AwayPlayer1  \
# 0         68.5         72.5          78.0          74.0         72.5
# 1         68.5         68.0          72.0          74.0         65.0
# 2         62.0         61.0           NaN          63.0         65.0
# 3         66.0         63.0          66.0          66.5         72.5
# 4         67.0         64.5          62.0           NaN         72.5
#
#    AwayPlayer2  AwayPlayer3  AwayPlayer4  AwayPlayer5  AwayPlayer6  \
# 0         72.0         68.5         71.5         67.5         69.0
# 1         72.0         68.0         67.0         72.0         67.5
# 2         72.0         67.5         70.0         72.0         72.5
# 3         72.0         68.0         67.0         70.0         67.5
# 4         72.0         68.5         69.5         70.0         67.5
#
#    AwayPlayer7  AwayPlayer8  AwayPlayer9  AwayPlayer10  AwayPlayer11  \
# 0         69.5         70.0         70.5          72.0          70.5
# 1         70.5         72.5         72.5          72.0          70.5
# 2         64.0         71.5         72.5          70.5          72.0
# 3         71.5         70.5         72.0          72.5          69.0
# 4         69.0         70.5         72.0          71.0          69.0
#
#    HomeShoton  AwayShoton  HomeShotoff  AwayShotoff  HomeFoulCommit  \
# 0         NaN         NaN          NaN          NaN             NaN
# 1         NaN         NaN          NaN          NaN             NaN
# 2         NaN         NaN          NaN          NaN             NaN
# 3         NaN         NaN          NaN          NaN             NaN
# 4         NaN         NaN          NaN          NaN             NaN
#
#    AwayFoulCommit  HomeCard  AwayCard  HomeCross  AwayCross  HomeCorner  \
# 0             NaN       NaN       NaN        NaN        NaN         NaN
# 1             NaN       NaN       NaN        NaN        NaN         NaN
# 2             NaN       NaN       NaN        NaN        NaN         NaN
# 3             NaN       NaN       NaN        NaN        NaN         NaN
# 4             NaN       NaN       NaN        NaN        NaN         NaN
#
#    AwayCorner    HomeTeamLongName HomeTeamShortName  HomeBuildUpPlaySpeed  \
# 0         NaN      RSC Anderlecht               AND                    50
# 1         NaN      RSC Anderlecht               AND                    50
# 2         NaN  Sporting Charleroi               CHA                    40
# 3         NaN         KV Mechelen               MEC                    65
# 4         NaN   Sint-Truidense VV               STT                    50
#
#    HomeBuildUpPlayPassing  HomeChanceCreationPassing  \
# 0                      35                         70
# 1                      35                         70
# 2                      50                         45
# 3                      60                         50
# 4                      50                         50
#
#    HomeChanceCreationCrossing  HomeChanceCreationShooting  \
# 0                          50                          60
# 1                          50                          60
# 2                          43                          60
# 3                          40                          50
# 4                          50                          50
#
#    HomeDefencePressure  HomeDefenceAggression  HomeDefenceTeamWidth  \
# 0                   70                     50                    70
# 1                   70                     50                    70
# 2                   70                     70                    70
# 3                   60                     70                    60
# 4                   50                     50                    50
#
#   AwayTeamLongName AwayTeamShortName  AwayBuildUpPlaySpeed  \
# 0   Club Brugge KV               CLB                    35
# 1   Club Brugge KV               CLB                    35
# 2   Club Brugge KV               CLB                    35
# 3   Club Brugge KV               CLB                    35
# 4   Club Brugge KV               CLB                    35
#
#    AwayBuildUpPlayPassing  AwayChanceCreationPassing  \
# 0                      40                         45
# 1                      40                         45
# 2                      40                         45
# 3                      40                         45
# 4                      40                         45
#
#    AwayChanceCreationCrossing  AwayChanceCreationShooting  \
# 0                          50                          45
# 1                          50                          45
# 2                          50                          45
# 3                          50                          45
# 4                          50                          45
#
#    AwayDefencePressure  AwayDefenceAggression  AwayDefenceTeamWidth
# 0                   60                     70                    70
# 1                   60                     70                    70
# 2                   60                     70                    70
# 3                   60                     70                    70
# 4                   60                     70                    70

# %%
def calculate_mean(df, column):
    df[column] = df[column].fillna(df[column].mean())
    
    return df

# %%
matches = matches.copy(deep=True)

# %%
columns_list = ['HomePlayer1',
 'HomePlayer2',
 'HomePlayer3',
 'HomePlayer4',
 'HomePlayer5',
 'HomePlayer6',
 'HomePlayer7',
 'HomePlayer8',
 'HomePlayer9',
 'HomePlayer10',
 'HomePlayer11',
 'AwayPlayer1',
 'AwayPlayer2',
 'AwayPlayer3',
 'AwayPlayer4',
 'AwayPlayer5',
 'AwayPlayer6',
 'AwayPlayer7',
 'AwayPlayer8',
 'AwayPlayer9',
 'AwayPlayer10',
 'AwayPlayer11',
 'HomeShoton',
 'AwayShoton',
 'HomeShotoff',
 'AwayShotoff',
 'HomeFoulCommit',
 'AwayFoulCommit',
 'HomeCard',
 'AwayCard',
 'HomeCross',
 'AwayCross',
 'HomeCorner',
 'AwayCorner']

# %%
column = columns_list

matches = round(calculate_mean(matches, column), 1)

# %%
matches.head()
# Out:
#    Date  LeagueID              LeagueName  MatchID  HomeTeamID  AwayTeamID  \
# 0  2010         1  Belgium Jupiler League   665626        8635        8342
# 1  2010         1  Belgium Jupiler League   838635        8635        8342
# 2  2010         1  Belgium Jupiler League   838544        9986        8342
# 3  2010         1  Belgium Jupiler League   838714        8203        8342
# 4  2010         1  Belgium Jupiler League   665737        9997        8342
#
#    HomeGoal  AwayGoal  TotalGoals  Result  HomePlayer1  HomePlayer2  \
# 0         3         2           5       1         72.0         72.5
# 1         2         2           4       0         72.0         74.0
# 2         0         5           5      -1         55.0         63.0
# 3         0         1           1      -1         69.5         63.5
# 4         1         1           2       0         68.5         69.9
#
#    HomePlayer3  HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  \
# 0         72.0         74.0         70.5         71.0         75.0
# 1         70.5         71.0         60.0         72.5         69.0
# 2         62.0         64.0         64.5         63.0         66.0
# 3         63.0         66.0         65.0         66.0         65.0
# 4         65.0         64.0         65.0         66.0         63.0
#
#    HomePlayer8  HomePlayer9  HomePlayer10  HomePlayer11  AwayPlayer1  \
# 0         68.5         72.5          78.0          74.0         72.5
# 1         68.5         68.0          72.0          74.0         65.0
# 2         62.0         61.0          72.5          63.0         65.0
# 3         66.0         63.0          66.0          66.5         72.5
# 4         67.0         64.5          62.0          72.7         72.5
#
#    AwayPlayer2  AwayPlayer3  AwayPlayer4  AwayPlayer5  AwayPlayer6  \
# 0         72.0         68.5         71.5         67.5         69.0
# 1         72.0         68.0         67.0         72.0         67.5
# 2         72.0         67.5         70.0         72.0         72.5
# 3         72.0         68.0         67.0         70.0         67.5
# 4         72.0         68.5         69.5         70.0         67.5
#
#    AwayPlayer7  AwayPlayer8  AwayPlayer9  AwayPlayer10  AwayPlayer11  \
# 0         69.5         70.0         70.5          72.0          70.5
# 1         70.5         72.5         72.5          72.0          70.5
# 2         64.0         71.5         72.5          70.5          72.0
# 3         71.5         70.5         72.0          72.5          69.0
# 4         69.0         70.5         72.0          71.0          69.0
#
#    HomeShoton  AwayShoton  HomeShotoff  AwayShotoff  HomeFoulCommit  \
# 0         3.5         2.8          3.5          2.8             7.0
# 1         3.5         2.8          3.5          2.8             7.0
# 2         3.5         2.8          3.5          2.8             7.0
# 3         3.5         2.8          3.5          2.8             7.0
# 4         3.5         2.8          3.5          2.8             7.0
#
#    AwayFoulCommit  HomeCard  AwayCard  HomeCross  AwayCross  HomeCorner  \
# 0             7.3       2.0       2.4       10.7        8.4         3.3
# 1             7.3       2.0       2.4       10.7        8.4         3.3
# 2             7.3       2.0       2.4       10.7        8.4         3.3
# 3             7.3       2.0       2.4       10.7        8.4         3.3
# 4             7.3       2.0       2.4       10.7        8.4         3.3
#
#    AwayCorner    HomeTeamLongName HomeTeamShortName  HomeBuildUpPlaySpeed  \
# 0         2.6      RSC Anderlecht               AND                    50
# 1         2.6      RSC Anderlecht               AND                    50
# 2         2.6  Sporting Charleroi               CHA                    40
# 3         2.6         KV Mechelen               MEC                    65
# 4         2.6   Sint-Truidense VV               STT                    50
#
#    HomeBuildUpPlayPassing  HomeChanceCreationPassing  \
# 0                      35                         70
# 1                      35                         70
# 2                      50                         45
# 3                      60                         50
# 4                      50                         50
#
#    HomeChanceCreationCrossing  HomeChanceCreationShooting  \
# 0                          50                          60
# 1                          50                          60
# 2                          43                          60
# 3                          40                          50
# 4                          50                          50
#
#    HomeDefencePressure  HomeDefenceAggression  HomeDefenceTeamWidth  \
# 0                   70                     50                    70
# 1                   70                     50                    70
# 2                   70                     70                    70
# 3                   60                     70                    60
# 4                   50                     50                    50
#
#   AwayTeamLongName AwayTeamShortName  AwayBuildUpPlaySpeed  \
# 0   Club Brugge KV               CLB                    35
# 1   Club Brugge KV               CLB                    35
# 2   Club Brugge KV               CLB                    35
# 3   Club Brugge KV               CLB                    35
# 4   Club Brugge KV               CLB                    35
#
#    AwayBuildUpPlayPassing  AwayChanceCreationPassing  \
# 0                      40                         45
# 1                      40                         45
# 2                      40                         45
# 3                      40                         45
# 4                      40                         45
#
#    AwayChanceCreationCrossing  AwayChanceCreationShooting  \
# 0                          50                          45
# 1                          50                          45
# 2                          50                          45
# 3                          50                          45
# 4                          50                          45
#
#    AwayDefencePressure  AwayDefenceAggression  AwayDefenceTeamWidth
# 0                   60                     70                    70
# 1                   60                     70                    70
# 2                   60                     70                    70
# 3                   60                     70                    70
# 4                   60                     70                    70

# %%
matches.isnull().sum()
# Out:
# Date                          0
# LeagueID                      0
# LeagueName                    0
# MatchID                       0
# HomeTeamID                    0
# AwayTeamID                    0
# HomeGoal                      0
# AwayGoal                      0
# TotalGoals                    0
# Result                        0
# HomePlayer1                   0
# HomePlayer2                   0
# HomePlayer3                   0
# HomePlayer4                   0
# HomePlayer5                   0
# HomePlayer6                   0
# HomePlayer7                   0
# HomePlayer8                   0
# HomePlayer9                   0
# HomePlayer10                  0
# HomePlayer11                  0
# AwayPlayer1                   0
# AwayPlayer2                   0
# AwayPlayer3                   0
# AwayPlayer4                   0
# AwayPlayer5                   0
# AwayPlayer6                   0
# AwayPlayer7                   0
# AwayPlayer8                   0
# AwayPlayer9                   0
# AwayPlayer10                  0
# AwayPlayer11                  0
# HomeShoton                    0
# AwayShoton                    0
# HomeShotoff                   0
# AwayShotoff                   0
# HomeFoulCommit                0
# AwayFoulCommit                0
# HomeCard                      0
# AwayCard                      0
# HomeCross                     0
# AwayCross                     0
# HomeCorner                    0
# AwayCorner                    0
# HomeTeamLongName              0
# HomeTeamShortName             0
# HomeBuildUpPlaySpeed          0
# HomeBuildUpPlayPassing        0
# HomeChanceCreationPassing     0
# HomeChanceCreationCrossing    0
# HomeChanceCreationShooting    0
# HomeDefencePressure           0
# HomeDefenceAggression         0
# HomeDefenceTeamWidth          0
# AwayTeamLongName              0
# AwayTeamShortName             0
# AwayBuildUpPlaySpeed          0
# AwayBuildUpPlayPassing        0
# AwayChanceCreationPassing     0
# AwayChanceCreationCrossing    0
# AwayChanceCreationShooting    0
# AwayDefencePressure           0
# AwayDefenceAggression         0
# AwayDefenceTeamWidth          0
# dtype: int64

# %%
matches.to_csv("C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches.csv")
