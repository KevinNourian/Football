# %% [markdown]
# ## Display Features

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings

from xml.etree.ElementTree import fromstring, ElementTree
import xml.etree.ElementTree as ET

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

# %% [markdown]
# # Load Datasets

# %% [markdown]
# ## Players

# %%
players = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\players1.csv",
    index_col=0,
)

# %%
players.head()
# Out:
#    PlayerID  Date PreferredFoot AttachWorkRate DefenceWorkRate  Birthday  \
# 0      2625  2007         right           high          medium    1981.0
# 1      2625  2008         right           high          medium    1981.0
# 2      2625  2010         right           high          medium    1981.0
# 3      2625  2011         right           high          medium    1981.0
# 4      2625  2012         right         medium          medium    1981.0
#
#    Height  Weight    BMI  OverallRating  Potential  Crossing  Finishing  \
# 0  175.26   154.0  22.74           63.0       64.0      48.0       48.0
# 1  175.26   154.0  22.74           60.0       64.0      48.0       48.0
# 2  175.26   154.0  22.74           60.0       64.0      48.0       48.0
# 3  175.26   154.0  22.74           58.5       60.5      52.0       47.0
# 4  175.26   154.0  22.74           58.0       58.0      52.0       47.0
#
#    HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FreeKickAccuracy  \
# ...

# %% [markdown]
# # Matches

# %%
matches = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches3.csv",
    index_col=0,
)

# %%
matches.head()
# Out:
#    Date  LeagueID              LeagueName  MatchID  HomeTeamID  AwayTeamID  \
# 0  2010         1  Belgium Jupiler League   665626        8635        8342
# 1  2010         1  Belgium Jupiler League   838635        8635        8342
# 2  2010         1  Belgium Jupiler League   838544        9986        8342
# 3  2010         1  Belgium Jupiler League   838714        8203        8342
# 4  2010         1  Belgium Jupiler League   665737        9997        8342
#
#    HomeGoal  AwayGoal  TotalGoals  HomePlayer1  HomePlayer2  HomePlayer3  \
# 0         3         2           5         72.0         72.5         72.0
# 1         2         2           4         72.0         74.0         70.5
# 2         0         5           5         55.0         63.0         62.0
# 3         0         1           1         69.5         63.5         63.0
# 4         1         1           2         68.5          NaN         65.0
#
#    HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  HomePlayer8  \
# ...

# %% [markdown]
# # Result

# %%
matches = matches.copy(deep=True)

matches['Result'] = matches['HomeGoal'] - matches['AwayGoal']
matches.loc[matches['Result'] < 0, 'Result'] = -1
matches.loc[matches['Result'] == 0, 'Result'] = 0
matches.loc[matches['Result'] > 0, 'Result'] = 1

result = matches.pop('Result')
matches.insert(9, 'Result', result)

# %%
matches.head()
# Out:
#    Date  LeagueID              LeagueName  MatchID  HomeTeamID  AwayTeamID  \
# 0  2010         1  Belgium Jupiler League   665626        8635        8342
# 1  2010         1  Belgium Jupiler League   838635        8635        8342
# 2  2010         1  Belgium Jupiler League   838544        9986        8342
# 3  2010         1  Belgium Jupiler League   838714        8203        8342
# 4  2010         1  Belgium Jupiler League   665737        9997        8342
#
#    HomeGoal  AwayGoal  TotalGoals  Result  HomePlayer1  HomePlayer2  \
# 0         3         2           5       1         72.0         72.5
# 1         2         2           4       0         72.0         74.0
# 2         0         5           5      -1         55.0         63.0
# 3         0         1           1      -1         69.5         63.5
# 4         1         1           2       0         68.5          NaN
#
#    HomePlayer3  HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  \
# ...

# %%
matches.to_csv("C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches4.csv")

# %%
matches = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches4.csv",
    index_col=0,
)

# %%
matches.head()
# Out:
#    Date  LeagueID              LeagueName  MatchID  HomeTeamID  AwayTeamID  \
# 0  2010         1  Belgium Jupiler League   665626        8635        8342
# 1  2010         1  Belgium Jupiler League   838635        8635        8342
# 2  2010         1  Belgium Jupiler League   838544        9986        8342
# 3  2010         1  Belgium Jupiler League   838714        8203        8342
# 4  2010         1  Belgium Jupiler League   665737        9997        8342
#
#    HomeGoal  AwayGoal  TotalGoals  Result  HomePlayer1  HomePlayer2  \
# 0         3         2           5       1         72.0         72.5
# 1         2         2           4       0         72.0         74.0
# 2         0         5           5      -1         55.0         63.0
# 3         0         1           1      -1         69.5         63.5
# 4         1         1           2       0         68.5          NaN
#
#    HomePlayer3  HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  \
# ...
