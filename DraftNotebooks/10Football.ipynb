# %% [markdown]
# ## Display Features

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings

from xml.etree.ElementTree import fromstring, ElementTree
import xml.etree.ElementTree as ET

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

# %% [markdown]
# # Load Datasets

# %% [markdown]
# ## Players

# %%
players = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\players.csv",
    index_col=0,
)

# %%
players.head()
# Out:
#    PlayerID  Date PreferredFoot AttachWorkRate DefenceWorkRate  Birthday  \
# 0      2625  2007         right           high          medium    1981.0
# 1      2625  2008         right           high          medium    1981.0
# 2      2625  2010         right           high          medium    1981.0
# 3      2625  2011         right           high          medium    1981.0
# 4      2625  2012         right         medium          medium    1981.0
#
#    Height  Weight    BMI  OverallRating  Potential  Crossing  Finishing  \
# 0  175.26   154.0  22.74           63.0       64.0      48.0       48.0
# 1  175.26   154.0  22.74           60.0       64.0      48.0       48.0
# 2  175.26   154.0  22.74           60.0       64.0      48.0       48.0
# 3  175.26   154.0  22.74           58.5       60.5      52.0       47.0
# 4  175.26   154.0  22.74           58.0       58.0      52.0       47.0
#
#    HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FreeKickAccuracy  \
# ...

# %%
players.shape
# Out:
# (71615, 39)

# %%
overall_rating = players[["Date", "PlayerID", "OverallRating"]]

# %% [markdown]
# ## Matches

# %%
matches = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches.csv",
    index_col=0,
)

# %%
sample_matches = matches[["Date", "HomePlayer1", "HomePlayer2"]]
df_merge = sample_matches

# %%
player = "HomePlayer1"
date = "Date"
player_id = "PlayerID"
rating_column = "OverallRating"
left_dataframe = overall_rating
right_dataframe = df_merge
left = [date, player_id]
right = [date, player]


def overall_function(left_dataframe, right_dataframe, left, right, player, player_id, rating_column, df_merge):

    df_merge = pd.merge(left_dataframe, right_dataframe, left_on=left, right_on=right)
    df_merge[player] = df_merge[rating_column]
    del df_merge[rating_column]
    del df_merge[player_id]

    return df_merge

# %%
df_merge = overall_function(left_dataframe, right_dataframe, left, right, player, player_id, rating_column, df_merge)

# %%
df_merge.head()
# Out:
#    Date  HomePlayer1  HomePlayer2
# 0  2010         74.0      21450.0
# 1  2010         74.0      21450.0
# 2  2010         74.0      38451.0
# 3  2010         74.0      21450.0
# 4  2010         74.0      21450.0

# %%
df_merge.shape
# Out:
# (17832, 3)

# %%
player = "HomePlayer2"

df_merge = overall_function(left_dataframe, right_dataframe, left, right, player, player_id, rating_column, df_merge)

# %%
df_merge.sort_values("Date").head()
# Out:
#        Date  HomePlayer1  HomePlayer2
# 0      2010       2984.0         74.0
# 11247  2010      42702.0         74.0
# 11246  2010      42702.0         74.0
# 11203  2010      42692.0         65.0
# 11199  2010      42573.0         72.5

# %%
df_merge.shape
# Out:
# (17832, 3)
