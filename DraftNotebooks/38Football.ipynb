# %% [markdown]
# ## Display Features

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings

from xml.etree.ElementTree import fromstring, ElementTree
import xml.etree.ElementTree as ET

# %%
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %% [markdown]
# # Players

# %%
players = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\players3.csv",
    index_col=0,
)

# %%
players.head()
# Out:
#    PlayerID  Date PreferredFoot AttackWorkRate DefenceWorkRate   Birthday  \
# 0      2625  2007         right           high          medium 1981.00000
# 1      2625  2008         right           high          medium 1981.00000
# 2      2625  2010         right           high          medium 1981.00000
# 3      2625  2011         right           high          medium 1981.00000
# 4      2625  2012         right         medium          medium 1981.00000
#
#      Height    Weight      BMI  OverallRating  Potential  Crossing  Finishing  \
# 0 175.26000 154.00000 22.74000       63.00000   64.00000  48.00000   48.00000
# 1 175.26000 154.00000 22.74000       60.00000   64.00000  48.00000   48.00000
# 2 175.26000 154.00000 22.74000       60.00000   64.00000  48.00000   48.00000
# 3 175.26000 154.00000 22.74000       58.50000   60.50000  52.00000   47.00000
# 4 175.26000 154.00000 22.74000       58.00000   58.00000  52.00000   47.00000
#
#    HeadingAccuracy  ShortPassing  Volleys  Dribbling    Curve  \
# 0         47.00000      64.00000 38.00000   57.00000 50.00000
# 1         47.00000      64.00000 38.00000   57.00000 50.00000
# 2         47.00000      64.00000 38.00000   57.00000 50.00000
# 3         46.00000      58.00000 37.00000   56.00000 49.00000
# 4         46.00000      53.00000 37.00000   56.00000 49.00000
#
#    FreeKickAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  \
# 0          48.50000     67.00000     57.00000      67.00000     64.00000
# 1          51.00000     67.00000     57.00000      67.00000     64.00000
# 2          51.00000     67.00000     57.00000      67.00000     64.00000
# 3          50.00000     66.00000     58.00000      66.00000     63.00000
# 4          50.00000     66.00000     58.00000      67.00000     63.00000
#
#    Agility  Reactions  Balance  ShotPower  Jumping  Stamina  Strength  \
# 0 59.00000   52.00000 49.00000   61.00000 56.00000 78.00000  56.00000
# 1 59.00000   52.00000 49.00000   61.00000 56.00000 78.00000  56.00000
# 2 59.00000   50.00000 49.00000   71.00000 56.00000 78.00000  56.00000
# 3 58.00000   49.00000 61.50000   68.00000 55.00000 77.00000  55.00000
# 4 67.00000   49.00000 76.00000   68.00000 55.00000 77.00000  55.50000
#
#    LongShots  Aggression  Interceptions  Positioning   Vision  Penalties  \
# 0   59.00000    72.00000       52.00000     55.00000 56.00000   46.00000
# 1   59.00000    72.00000       52.00000     55.00000 56.00000   46.00000
# 2   59.00000    72.00000       71.00000     50.00000 56.00000   69.00000
# 3   58.00000    71.00000       65.00000     49.00000 55.00000   66.00000
# 4   58.00000    71.00000       64.00000     49.00000 55.00000   66.00000
#
#    Marking  StandingTackle  SlidingTackle  MeanofAttributes
# 0 64.00000        66.00000       63.00000          56.43000
# 1 64.00000        66.00000       63.00000          56.41000
# 2 64.00000        66.00000       63.00000          57.86000
# 3 63.00000        63.00000       57.00000          56.78000
# 4 63.00000        63.00000       52.00000          57.14000

# %%
sns.catplot(x = 'PreferredFoot', y='OverallRating', data = players, kind = 'box')

# %%
sns.catplot(x = 'Birthday', y='OverallRating', data = players, kind = 'box', col = 'PreferredFoot')
