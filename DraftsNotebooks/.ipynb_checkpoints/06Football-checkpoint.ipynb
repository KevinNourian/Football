# %% [markdown]
# ## Display Features

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings

from xml.etree.ElementTree import fromstring, ElementTree
import xml.etree.ElementTree as ET

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

# %% [markdown]
# # Load Datasets

# %%
players = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\players1.csv",
    index_col=0,
)

# %%
players.head()
# Out:
#    PlayerID          PlayerName  Birthday  Height  Weight    BMI  Date  \
# 0    505942  Aaron Appindangoye      1992  182.88     187  25.36  2016
# 1    505942  Aaron Appindangoye      1992  182.88     187  25.36  2015
# 2    505942  Aaron Appindangoye      1992  182.88     187  25.36  2015
# 3    505942  Aaron Appindangoye      1992  182.88     187  25.36  2015
# 4    505942  Aaron Appindangoye      1992  182.88     187  25.36  2007
#
#    OverallRating  Potential PreferredFoot AttachWorkRate DefenceWorkRate  \
# 0           67.0       71.0         right         medium          medium
# 1           67.0       71.0         right         medium          medium
# 2           62.0       66.0         right         medium          medium
# 3           61.0       65.0         right         medium          medium
# 4           61.0       65.0         right         medium          medium
#
#    Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# ...

# %%
teams = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\teams1.csv",
    index_col=0,
)

# %%
teams.head()
# Out:
#    TeamID TeamLongName TeamShortName  Date  BuildUpPlaySpeed  \
# 0    9987     KRC Genk           GEN  2010                45
# 1    9987     KRC Genk           GEN  2011                66
# 2    9987     KRC Genk           GEN  2012                53
# 3    9987     KRC Genk           GEN  2013                58
# 4    9987     KRC Genk           GEN  2014                58
#
#    BuildUpPlayPassing  ChanceCreationPassing  ChanceCreationCrossing  \
# 0                  45                     50                      35
# 1                  52                     65                      66
# 2                  55                     55                      48
# 3                  38                     67                      48
# 4                  38                     67                      48
#
#    ChanceCreationShooting  DefencePressure  DefenceAggression  \
# 0                      60               70                 65
# ...

# %%
matches = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches1.csv",
    index_col=0,
)

# %%
matches.head()
# Out:
#    LeagueID              LeagueName     Season  Date  MatchID  HomeTeamID  \
# 0         1  Belgium Jupiler League  2008/2009     8   492473        9987
# 1         1  Belgium Jupiler League  2008/2009     8   492474       10000
# 2         1  Belgium Jupiler League  2008/2009     8   492475        9984
# 3         1  Belgium Jupiler League  2008/2009     8   492476        9991
# 4         1  Belgium Jupiler League  2008/2009     8   492477        7947
#
#    AwayTeamID  HomeTeamGoal  AwayTeamGoal  TotalGoals  ShotonHome  ShotonAway  \
# 0        9993             1             1           2         NaN         NaN
# 1        9994             0             0           0         NaN         NaN
# 2        8635             0             3           3         NaN         NaN
# 3        9998             5             0           5         NaN         NaN
# 4        9985             1             3           4         NaN         NaN
#
# ...
