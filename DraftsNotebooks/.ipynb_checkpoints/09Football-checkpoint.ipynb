# %% [markdown]
# ## Display Features

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings

from xml.etree.ElementTree import fromstring, ElementTree
import xml.etree.ElementTree as ET

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

# %% [markdown]
# # Load Datasets

# %% [markdown]
# ## Players

# %%
players = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\players.csv",
    index_col=0,
)

# %%
players.head()
# Out:
#    PlayerID  Date PreferredFoot AttachWorkRate DefenceWorkRate  Birthday  \
# 0      2625  2007         right           high          medium    1981.0
# 1      2625  2008         right           high          medium    1981.0
# 2      2625  2010         right           high          medium    1981.0
# 3      2625  2011         right           high          medium    1981.0
# 4      2625  2012         right         medium          medium    1981.0
#
#    Height  Weight    BMI  OverallRating  Potential  Crossing  Finishing  \
# 0  175.26   154.0  22.74           63.0       64.0      48.0       48.0
# 1  175.26   154.0  22.74           60.0       64.0      48.0       48.0
# 2  175.26   154.0  22.74           60.0       64.0      48.0       48.0
# 3  175.26   154.0  22.74           58.5       60.5      52.0       47.0
# 4  175.26   154.0  22.74           58.0       58.0      52.0       47.0
#
#    HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FreeKickAccuracy  \
# ...

# %%
overall_rating = players[["Date", "PlayerID", "OverallRating"]]

# %% [markdown]
# ## Matches

# %%
matches = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches.csv",
    index_col=0,
)

# %%
matches.head()
# Out:
#    LeagueID              LeagueName  Date  MatchID  HomeTeamID  AwayTeamID  \
# 0         1  Belgium Jupiler League  2010   665626        8635        8342
# 1         1  Belgium Jupiler League  2010   838635        8635        8342
# 2         1  Belgium Jupiler League  2010   838544        9986        8342
# 3         1  Belgium Jupiler League  2010   838714        8203        8342
# 4         1  Belgium Jupiler League  2010   665737        9997        8342
#
#    HomeGoal  AwayGoal  HomePlayer1  HomePlayer2  HomePlayer3  HomePlayer4  \
# 0         3         2      38391.0      33620.0      38388.0      38389.0
# 1         2         2      38391.0      38389.0      38253.0      69713.0
# 2         0         5     104388.0      39977.0      93054.0      46666.0
# 3         0         1      39573.0      67950.0      39389.0      80184.0
# 4         1         1      37868.0      33595.0      37866.0       3329.0
#
#    HomePlayer5  HomePlayer6  HomePlayer7  HomePlayer8  HomePlayer9  \
# ...

# %%
overall_rating.head()
# Out:
#    Date  PlayerID  OverallRating
# 0  2007      2625           63.0
# 1  2008      2625           60.0
# 2  2010      2625           60.0
# 3  2011      2625           58.5
# 4  2012      2625           58.0

# %%
sample_matches = matches[["Date", "HomePlayer1", "HomePlayer2"]]
sample_matches.head()
df_merge = sample_matches

# %%
df_merge = pd.merge(overall_rating, df_merge, left_on=["Date", "PlayerID"], right_on=["Date","HomePlayer1"])

# %%
df_merge['HomePlayer1'] = df_merge['OverallRating']

# %%
del df_merge["OverallRating"]

# %%
del df_merge["PlayerID"]

# %%
df_merge.head()
# Out:
#    Date  HomePlayer1  HomePlayer2
# 0  2010         74.0      21450.0
# 1  2010         74.0      21450.0
# 2  2010         74.0      38451.0
# 3  2010         74.0      21450.0
# 4  2010         74.0      21450.0

# %%
df_merge.shape
# Out:
# (17832, 3)

# %%
df_merge = pd.merge(overall_rating, df_merge, left_on=["Date", "PlayerID"], right_on=["Date","HomePlayer2"])

# %%
df_merge['HomePlayer2'] = df_merge['OverallRating']

# %%
del df_merge["OverallRating"]

# %%
del df_merge["PlayerID"]

# %%
df_merge.sort_values("Date").head()
# Out:
#       Date  HomePlayer1  HomePlayer2
# 0     2010         78.0         81.0
# 2739  2010         77.0         72.5
# 2740  2010         77.0         72.5
# 2741  2010         81.0         73.5
# 7524  2010         77.5         71.5

# %%
df_merge.shape
# Out:
# (17374, 3)
