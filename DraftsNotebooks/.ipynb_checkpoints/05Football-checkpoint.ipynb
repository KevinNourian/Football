# %% [markdown]
# ## Display Features

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings

from xml.etree.ElementTree import fromstring, ElementTree
import xml.etree.ElementTree as ET

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

# %% [markdown]
# # Load Dataset

# %%
football = sqlite3.connect(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\database.sqlite"
)

# %% [markdown]
# # List of Tables

# %%
football_db = {}

result = football.execute("SELECT name FROM sqlite_master WHERE type='table';")

for table in result:
    query = "SELECT * from " + str(table[0]) + ";"
    football_db[table[0]] = pd.read_sql_query(query, football)

football_db.keys()
# Out:
# dict_keys(['sqlite_sequence', 'Player_Attributes', 'Player', 'Match', 'League', 'Country', 'Team', 'Team_Attributes'])

# %% [markdown]
# # Country

# %%
country = football_db["Country"].copy()

# %%
country.rename(columns={"id": "LeagueID", "name": "CountryName"}, inplace=True)

# %%
country
# Out:
#     LeagueID  CountryName
# 0          1      Belgium
# 1       1729      England
# 2       4769       France
# 3       7809      Germany
# 4      10257        Italy
# 5      13274  Netherlands
# 6      15722       Poland
# 7      17642     Portugal
# 8      19694     Scotland
# 9      21518        Spain
# 10     24558  Switzerland

# %%
country.shape
# Out:
# (11, 2)

# %% [markdown]
# # League

# %%
league = football_db["League"].copy()

# %%
del league["id"]

# %%
league.rename(columns={"country_id": "LeagueID", "name": "LeagueName"}, inplace=True)

# %%
league
# Out:
#     LeagueID                LeagueName
# 0          1    Belgium Jupiler League
# 1       1729    England Premier League
# 2       4769            France Ligue 1
# 3       7809     Germany 1. Bundesliga
# 4      10257             Italy Serie A
# 5      13274    Netherlands Eredivisie
# 6      15722        Poland Ekstraklasa
# 7      17642  Portugal Liga ZON Sagres
# 8      19694   Scotland Premier League
# 9      21518           Spain LIGA BBVA
# 10     24558  Switzerland Super League

# %%
league.shape
# Out:
# (11, 2)

# %% [markdown]
# # Player

# %%
player = football_db["Player"].copy()

# %%
player["birthday"] = pd.DatetimeIndex(player["birthday"]).year

# %%
player.drop(columns=["id", "player_fifa_api_id"], inplace=True)

# %%
player.rename(
    columns={
        "player_api_id": "PlayerID",
        "player_name": "PlayerName",
        "birthday": "Birthday",
        "height": "Height",
        "weight": "Weight",
    },
    inplace=True,
)

# %%
player["BMI"] = np.round((player["Weight"] / 2.205) / ((player["Height"] / 100.0) ** 2),2)

# %%
player.head()
# Out:
#    PlayerID          PlayerName  Birthday  Height  Weight    BMI
# 0    505942  Aaron Appindangoye      1992  182.88     187  25.36
# 1    155782     Aaron Cresswell      1989  170.18     146  22.86
# 2    162549         Aaron Doran      1991  170.18     163  25.52
# 3     30572       Aaron Galindo      1982  182.88     198  26.85
# 4     23780        Aaron Hughes      1979  182.88     154  20.88

# %%
player.shape
# Out:
# (11060, 6)

# %%
player[player.duplicated(keep=False)].any()
# Out:
# PlayerID      False
# PlayerName    False
# Birthday      False
# Height        False
# Weight        False
# BMI           False
# dtype: bool

# %% [markdown]
# # Team

# %%
team = football_db["Team"].copy()

# %%
team.drop(
    columns=[
        "id",
        "team_fifa_api_id",
    ],
    inplace=True,
)

# %%
team.rename(
    columns={
        "team_api_id": "TeamID",
        "team_long_name": "TeamLongName",
        "team_short_name": "TeamShortName",
    },
    inplace=True,
)

# %%
team.head()
# Out:
#    TeamID       TeamLongName TeamShortName
# 0    9987           KRC Genk           GEN
# 1    9993       Beerschot AC           BAC
# 2   10000   SV Zulte-Waregem           ZUL
# 3    9994   Sporting Lokeren           LOK
# 4    9984  KSV Cercle Brugge           CEB

# %%
team.shape
# Out:
# (299, 3)

# %%
team[team.duplicated(keep=False)].any()
# Out:
# TeamID           False
# TeamLongName     False
# TeamShortName    False
# dtype: bool

# %% [markdown]
# # Player Attributes

# %%
player_attributes = football_db["Player_Attributes"].copy()

# %%
player_attributes.head()
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
#    finishing  heading_accuracy  short_passing  volleys  dribbling  curve  \
# 0       44.0              71.0           61.0     44.0       51.0   45.0
# 1       44.0              71.0           61.0     44.0       51.0   45.0
# 2       44.0              71.0           61.0     44.0       51.0   45.0
# 3       43.0              70.0           60.0     43.0       50.0   44.0
# 4       43.0              70.0           60.0     43.0       50.0   44.0
#
#    free_kick_accuracy  long_passing  ball_control  acceleration  sprint_speed  \
# 0                39.0          64.0          49.0          60.0          64.0
# 1                39.0          64.0          49.0          60.0          64.0
# 2                39.0          64.0          49.0          60.0          64.0
# 3                38.0          63.0          48.0          60.0          64.0
# 4                38.0          63.0          48.0          60.0          64.0
#
#    agility  reactions  balance  shot_power  jumping  stamina  strength  \
# 0     59.0       47.0     65.0        55.0     58.0     54.0      76.0
# 1     59.0       47.0     65.0        55.0     58.0     54.0      76.0
# 2     59.0       47.0     65.0        55.0     58.0     54.0      76.0
# 3     59.0       46.0     65.0        54.0     58.0     54.0      76.0
# 4     59.0       46.0     65.0        54.0     58.0     54.0      76.0
#
#    long_shots  aggression  interceptions  positioning  vision  penalties  \
# 0        35.0        71.0           70.0         45.0    54.0       48.0
# 1        35.0        71.0           70.0         45.0    54.0       48.0
# 2        35.0        63.0           41.0         45.0    54.0       48.0
# 3        34.0        62.0           40.0         44.0    53.0       47.0
# 4        34.0        62.0           40.0         44.0    53.0       47.0
#
#    marking  standing_tackle  sliding_tackle  gk_diving  gk_handling  \
# 0     65.0             69.0            69.0        6.0         11.0
# 1     65.0             69.0            69.0        6.0         11.0
# 2     65.0             66.0            69.0        6.0         11.0
# 3     62.0             63.0            66.0        5.0         10.0
# 4     62.0             63.0            66.0        5.0         10.0
#
#    gk_kicking  gk_positioning  gk_reflexes
# 0        10.0             8.0          8.0
# 1        10.0             8.0          8.0
# 2        10.0             8.0          8.0
# 3         9.0             7.0          7.0
# 4         9.0             7.0          7.0

# %%
player_attributes.drop(
    columns=[
        "id",
        "player_fifa_api_id",
        "gk_diving",
        "gk_handling",
        "gk_kicking",
        "gk_positioning",
        "gk_reflexes",
    ],
    inplace=True,
)

# %%
player_attributes.rename(
    columns={
        "player_api_id": "PlayerID",
        "date": "Date",
        "overall_rating": "OverallRating",
        "potential": "Potential",
        "preferred_foot": "PreferredFoot",
        "attacking_work_rate": "AttachWorkRate",
        "defensive_work_rate": "DefenceWorkRate",
        "crossing": "Crossing",
        "finishing": "Finishing",
        "heading_accuracy": "HeadingAccuracy",
        "short_passing": "ShortPassing",
        "volleys": "Volleys",
        "dribbling": "Dribbling",
        "curve": "Curve",
        "free_kick_accuracy": "FreeKickAccuracy",
        "long_passing": "LongPassing",
        "ball_control": "BallControl",
        "acceleration": "Acceleration",
        "sprint_speed": "SprintSpeed",
        "agility": "Agility",
        "reactions": "Reactions",
        "balance": "Balance",
        "shot_power": "ShotPower",
        "jumping": "Jumping",
        "stamina": "Stamina",
        "strength": "Strength",
        "long_shots": "LongShots",
        "aggression": "Aggression",
        "interceptions": "Interceptions",
        "positioning": "Positioning",
        "vision": "Vision",
        "penalties": "Penalties",
        "marking": "Marking",
        "standing_tackle": "StandingTackle",
        "sliding_tackle": "SlidingTackle",
    },
    inplace=True,
)

# %%
player_attributes["Date"] = pd.DatetimeIndex(player_attributes["Date"]).year

# %%
null_instances = player_attributes[player_attributes["OverallRating"].isnull()].index

# %%
player_attributes.drop(null_instances, inplace=True)

# %%
null_instances = player_attributes[player_attributes["Volleys"].isnull()].index

# %%
player_attributes.drop(null_instances, inplace=True)

# %%
players = pd.merge(player, player_attributes, on="PlayerID", how="inner")

# %%
players.head()
# Out:
#    PlayerID          PlayerName  Birthday  Height  Weight    BMI  Date  \
# 0    505942  Aaron Appindangoye      1992  182.88     187  25.36  2016
# 1    505942  Aaron Appindangoye      1992  182.88     187  25.36  2015
# 2    505942  Aaron Appindangoye      1992  182.88     187  25.36  2015
# 3    505942  Aaron Appindangoye      1992  182.88     187  25.36  2015
# 4    505942  Aaron Appindangoye      1992  182.88     187  25.36  2007
#
#    OverallRating  Potential PreferredFoot AttachWorkRate DefenceWorkRate  \
# 0           67.0       71.0         right         medium          medium
# 1           67.0       71.0         right         medium          medium
# 2           62.0       66.0         right         medium          medium
# 3           61.0       65.0         right         medium          medium
# 4           61.0       65.0         right         medium          medium
#
#    Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0      49.0       44.0             71.0          61.0     44.0       51.0
# 1      49.0       44.0             71.0          61.0     44.0       51.0
# 2      49.0       44.0             71.0          61.0     44.0       51.0
# 3      48.0       43.0             70.0          60.0     43.0       50.0
# 4      48.0       43.0             70.0          60.0     43.0       50.0
#
#    Curve  FreeKickAccuracy  LongPassing  BallControl  Acceleration  \
# 0   45.0              39.0         64.0         49.0          60.0
# 1   45.0              39.0         64.0         49.0          60.0
# 2   45.0              39.0         64.0         49.0          60.0
# 3   44.0              38.0         63.0         48.0          60.0
# 4   44.0              38.0         63.0         48.0          60.0
#
#    SprintSpeed  Agility  Reactions  Balance  ShotPower  Jumping  Stamina  \
# 0         64.0     59.0       47.0     65.0       55.0     58.0     54.0
# 1         64.0     59.0       47.0     65.0       55.0     58.0     54.0
# 2         64.0     59.0       47.0     65.0       55.0     58.0     54.0
# 3         64.0     59.0       46.0     65.0       54.0     58.0     54.0
# 4         64.0     59.0       46.0     65.0       54.0     58.0     54.0
#
#    Strength  LongShots  Aggression  Interceptions  Positioning  Vision  \
# 0      76.0       35.0        71.0           70.0         45.0    54.0
# 1      76.0       35.0        71.0           70.0         45.0    54.0
# 2      76.0       35.0        63.0           41.0         45.0    54.0
# 3      76.0       34.0        62.0           40.0         44.0    53.0
# 4      76.0       34.0        62.0           40.0         44.0    53.0
#
#    Penalties  Marking  StandingTackle  SlidingTackle
# 0       48.0     65.0            69.0           69.0
# 1       48.0     65.0            69.0           69.0
# 2       48.0     65.0            66.0           69.0
# 3       47.0     62.0            63.0           66.0
# 4       47.0     62.0            63.0           66.0

# %%
def break_ties(col: str):
    most_common = pd.Series.mode(col)

    if len(most_common) > 1:
        return most_common[0]
    else:
        return most_common

# %%
players_categorical = (
    players.groupby(["PlayerID", "Date"])[
        ["PreferredFoot", "AttachWorkRate", "DefenceWorkRate"]
    ]
    .agg(lambda x: break_ties(x))
    .reset_index()
)

# %%
players_numerical = (
    players.groupby(["PlayerID", "Date"])
    .agg("mean", numeric_only=True)
    .reset_index()
)

# %%
players = pd.merge(
    players_categorical,
    players_numerical,
    on=["PlayerID", "Date"],
    how="inner",
)

# %%
players.to_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\players.csv",
    index=True,
    header=True,
    encoding="utf-8",
)

# %%
players = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\players.csv",
    index_col=0,
)

# %%
players.head()
# Out:
#    PlayerID  Date PreferredFoot AttachWorkRate DefenceWorkRate  Birthday  \
# 0      2625  2007         right           high          medium    1981.0
# 1      2625  2008         right           high          medium    1981.0
# 2      2625  2010         right           high          medium    1981.0
# 3      2625  2011         right           high          medium    1981.0
# 4      2625  2012         right         medium          medium    1981.0
#
#    Height  Weight    BMI  OverallRating  Potential  Crossing  Finishing  \
# 0  175.26   154.0  22.74           63.0       64.0      48.0       48.0
# 1  175.26   154.0  22.74           60.0       64.0      48.0       48.0
# 2  175.26   154.0  22.74           60.0       64.0      48.0       48.0
# 3  175.26   154.0  22.74           58.5       60.5      52.0       47.0
# 4  175.26   154.0  22.74           58.0       58.0      52.0       47.0
#
#    HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FreeKickAccuracy  \
# 0             47.0          64.0     38.0       57.0   50.0              48.5
# 1             47.0          64.0     38.0       57.0   50.0              51.0
# 2             47.0          64.0     38.0       57.0   50.0              51.0
# 3             46.0          58.0     37.0       56.0   49.0              50.0
# 4             46.0          53.0     37.0       56.0   49.0              50.0
#
#    LongPassing  BallControl  Acceleration  SprintSpeed  Agility  Reactions  \
# 0         67.0         57.0          67.0         64.0     59.0       52.0
# 1         67.0         57.0          67.0         64.0     59.0       52.0
# 2         67.0         57.0          67.0         64.0     59.0       50.0
# 3         66.0         58.0          66.0         63.0     58.0       49.0
# 4         66.0         58.0          67.0         63.0     67.0       49.0
#
#    Balance  ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 0     49.0       61.0     56.0     78.0      56.0       59.0        72.0
# 1     49.0       61.0     56.0     78.0      56.0       59.0        72.0
# 2     49.0       71.0     56.0     78.0      56.0       59.0        72.0
# 3     61.5       68.0     55.0     77.0      55.0       58.0        71.0
# 4     76.0       68.0     55.0     77.0      55.5       58.0        71.0
#
#    Interceptions  Positioning  Vision  Penalties  Marking  StandingTackle  \
# 0           52.0         55.0    56.0       46.0     64.0            66.0
# 1           52.0         55.0    56.0       46.0     64.0            66.0
# 2           71.0         50.0    56.0       69.0     64.0            66.0
# 3           65.0         49.0    55.0       66.0     63.0            63.0
# 4           64.0         49.0    55.0       66.0     63.0            63.0
#
#    SlidingTackle
# 0           63.0
# 1           63.0
# 2           63.0
# 3           57.0
# 4           52.0

# %%
players.shape
# Out:
# (71615, 39)

# %% [markdown]
# # Team Attributes

# %%
team_attributes = football_db["Team_Attributes"].copy()

# %%
team_attributes.shape
# Out:
# (1458, 25)

# %%
team_attributes.drop(
    columns=[
        "id",
        "team_fifa_api_id",
        "buildUpPlayDribbling",
        "buildUpPlaySpeedClass",
        "buildUpPlayDribblingClass",
        "buildUpPlayPassingClass",
        "buildUpPlayPositioningClass",
        "chanceCreationPassingClass",
        "chanceCreationCrossingClass",
        "chanceCreationShootingClass",
        "chanceCreationPositioningClass",
        "defencePressureClass",
        "defenceAggressionClass",
        "defenceTeamWidthClass",
        "defenceDefenderLineClass",
    ],
    inplace=True,
)

# %%
team_attributes.rename(
    columns={
        "team_api_id": "TeamID",
        "date": "Date",
        "buildUpPlaySpeed": "BuildUpPlaySpeed",
        "buildUpPlayPassing": "BuildUpPlayPassing",
        "chanceCreationPassing": "ChanceCreationPassing",
        "chanceCreationCrossing": "ChanceCreationCrossing",
        "chanceCreationShooting": "ChanceCreationShooting",
        "defencePressure": "DefencePressure",
        "defenceAggression": "DefenceAggression",
        "defenceTeamWidth": "DefenceTeamWidth",
    },
    inplace=True,
)

# %%
team_attributes["Date"] = pd.DatetimeIndex(team_attributes["Date"]).year

# %%
teams = pd.merge(team, team_attributes, on="TeamID", how="inner")

# %%
teams.head()
# Out:
#    TeamID TeamLongName TeamShortName  Date  BuildUpPlaySpeed  \
# 0    9987     KRC Genk           GEN  2010                45
# 1    9987     KRC Genk           GEN  2011                66
# 2    9987     KRC Genk           GEN  2012                53
# 3    9987     KRC Genk           GEN  2013                58
# 4    9987     KRC Genk           GEN  2014                58
#
#    BuildUpPlayPassing  ChanceCreationPassing  ChanceCreationCrossing  \
# 0                  45                     50                      35
# 1                  52                     65                      66
# 2                  55                     55                      48
# 3                  38                     67                      48
# 4                  38                     67                      48
#
#    ChanceCreationShooting  DefencePressure  DefenceAggression  \
# 0                      60               70                 65
# 1                      51               48                 47
# 2                      56               47                 45
# 3                      56               47                 45
# 4                      56               47                 45
#
#    DefenceTeamWidth
# 0                70
# 1                54
# 2                55
# 3                55
# 4                55

# %%
teams.to_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\teams.csv",
    index=True,
    header=True,
    encoding="utf-8",
)

# %%
teams = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\teams.csv",
    index_col=0,
)

# %%
teams.head()
# Out:
#    TeamID TeamLongName TeamShortName  Date  BuildUpPlaySpeed  \
# 0    9987     KRC Genk           GEN  2010                45
# 1    9987     KRC Genk           GEN  2011                66
# 2    9987     KRC Genk           GEN  2012                53
# 3    9987     KRC Genk           GEN  2013                58
# 4    9987     KRC Genk           GEN  2014                58
#
#    BuildUpPlayPassing  ChanceCreationPassing  ChanceCreationCrossing  \
# 0                  45                     50                      35
# 1                  52                     65                      66
# 2                  55                     55                      48
# 3                  38                     67                      48
# 4                  38                     67                      48
#
#    ChanceCreationShooting  DefencePressure  DefenceAggression  \
# 0                      60               70                 65
# 1                      51               48                 47
# 2                      56               47                 45
# 3                      56               47                 45
# 4                      56               47                 45
#
#    DefenceTeamWidth
# 0                70
# 1                54
# 2                55
# 3                55
# 4                55

# %%
teams.shape
# Out:
# (1458, 12)

# %% [markdown]
# # Match

# %%
def extract_xml(row, col_name, xml_key, away_home):
    count = 0

    element = row[col_name]
    team_id = row[away_home + "_team_api_id"]

    if type(element) == int:
        return element

    elif element != None:
        tree = ElementTree(fromstring(element))
        root = tree.getroot()

        for child in root.iter(xml_key):
            if str(team_id) == child.text:
                count += 1
        return count
    else:
        return np.nan

# %%
def extract_possession_xml(row, col_name, xml_key):
    count = 0
    sum_pos = 0

    element = row[col_name]

    if type(element) == int:
        return element

    elif element != None:
        tree = ElementTree(fromstring(element))
        root = tree.getroot()
        for child in root.iter(xml_key):
            count += 1
            sum_pos += int(child.text)

        if count == 0:
            return np.nan
        else:
            return sum_pos / count
    else:
        return np.nan

# %%
match = football_db["Match"].copy()

# %%
match.head()
# Out:
#    id  country_id  league_id     season  stage                 date  \
# 0   1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1   2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2   3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3   4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4   5           1          1  2008/2009      1  2008-08-16 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 0        492473              9987              9993               1
# 1        492474             10000              9994               0
# 2        492475              9984              8635               0
# 3        492476              9991              9998               5
# 4        492477              7947              9985               1
#
#    away_team_goal  home_player_X1  home_player_X2  home_player_X3  \
# 0               1             NaN             NaN             NaN
# 1               0             NaN             NaN             NaN
# 2               3             NaN             NaN             NaN
# 3               0             NaN             NaN             NaN
# 4               3             NaN             NaN             NaN
#
#    home_player_X4  home_player_X5  home_player_X6  home_player_X7  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    home_player_X8  home_player_X9  home_player_X10  home_player_X11  \
# 0             NaN             NaN              NaN              NaN
# 1             NaN             NaN              NaN              NaN
# 2             NaN             NaN              NaN              NaN
# 3             NaN             NaN              NaN              NaN
# 4             NaN             NaN              NaN              NaN
#
#    away_player_X1  away_player_X2  away_player_X3  away_player_X4  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    away_player_X5  away_player_X6  away_player_X7  away_player_X8  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    away_player_X9  away_player_X10  away_player_X11  home_player_Y1  \
# 0             NaN              NaN              NaN             NaN
# 1             NaN              NaN              NaN             NaN
# 2             NaN              NaN              NaN             NaN
# 3             NaN              NaN              NaN             NaN
# 4             NaN              NaN              NaN             NaN
#
#    home_player_Y2  home_player_Y3  home_player_Y4  home_player_Y5  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    home_player_Y6  home_player_Y7  home_player_Y8  home_player_Y9  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    home_player_Y10  home_player_Y11  away_player_Y1  away_player_Y2  \
# 0              NaN              NaN             NaN             NaN
# 1              NaN              NaN             NaN             NaN
# 2              NaN              NaN             NaN             NaN
# 3              NaN              NaN             NaN             NaN
# 4              NaN              NaN             NaN             NaN
#
#    away_player_Y3  away_player_Y4  away_player_Y5  away_player_Y6  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    away_player_Y7  away_player_Y8  away_player_Y9  away_player_Y10  \
# 0             NaN             NaN             NaN              NaN
# 1             NaN             NaN             NaN              NaN
# 2             NaN             NaN             NaN              NaN
# 3             NaN             NaN             NaN              NaN
# 4             NaN             NaN             NaN              NaN
#
#    away_player_Y11  home_player_1  home_player_2  home_player_3  \
# 0              NaN            NaN            NaN            NaN
# 1              NaN            NaN            NaN            NaN
# 2              NaN            NaN            NaN            NaN
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
#
#    home_player_4  home_player_5  home_player_6  home_player_7  home_player_8  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    home_player_9  home_player_10  home_player_11  away_player_1  \
# 0            NaN             NaN             NaN            NaN
# 1            NaN             NaN             NaN            NaN
# 2            NaN             NaN             NaN            NaN
# 3            NaN             NaN             NaN            NaN
# 4            NaN             NaN             NaN            NaN
#
#    away_player_2  away_player_3  away_player_4  away_player_5  away_player_6  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    away_player_7  away_player_8  away_player_9  away_player_10  \
# 0            NaN            NaN            NaN             NaN
# 1            NaN            NaN            NaN             NaN
# 2            NaN            NaN            NaN             NaN
# 3            NaN            NaN            NaN             NaN
# 4            NaN            NaN            NaN             NaN
#
#    away_player_11  goal shoton shotoff foulcommit  card cross corner  \
# 0             NaN  None   None    None       None  None  None   None
# 1             NaN  None   None    None       None  None  None   None
# 2             NaN  None   None    None       None  None  None   None
# 3             NaN  None   None    None       None  None  None   None
# 4             NaN  None   None    None       None  None  None   None
#
#   possession  B365H  B365D  B365A   BWH   BWD   BWA   IWH  IWD  IWA   LBH  \
# 0       None   1.73   3.40   5.00  1.75  3.35  4.20  1.85  3.2  3.5  1.80
# 1       None   1.95   3.20   3.60  1.80  3.30  3.95  1.90  3.2  3.5  1.90
# 2       None   2.38   3.30   2.75  2.40  3.30  2.55  2.60  3.1  2.3  2.50
# 3       None   1.44   3.75   7.50  1.40  4.00  6.80  1.40  3.9  6.0  1.44
# 4       None   5.00   3.50   1.65  5.00  3.50  1.60  4.00  3.3  1.7  4.00
#
#    LBD   LBA  PSH  PSD  PSA   WHH   WHD   WHA   SJH  SJD   SJA   VCH   VCD  \
# 0  3.3  3.75  NaN  NaN  NaN  1.70  3.30  4.33  1.90  3.3  4.00  1.65  3.40
# 1  3.2  3.50  NaN  NaN  NaN  1.83  3.30  3.60  1.95  3.3  3.80  2.00  3.25
# 2  3.2  2.50  NaN  NaN  NaN  2.50  3.25  2.40  2.63  3.3  2.50  2.35  3.25
# 3  3.6  6.50  NaN  NaN  NaN  1.44  3.75  6.00  1.44  4.0  7.50  1.45  3.75
# 4  3.4  1.72  NaN  NaN  NaN  4.20  3.40  1.70  4.50  3.5  1.73  4.50  3.40
#
#     VCA   GBH   GBD   GBA   BSH   BSD   BSA
# 0  4.50  1.78  3.25  4.00  1.73  3.40  4.20
# 1  3.25  1.85  3.25  3.75  1.91  3.25  3.60
# 2  2.65  2.50  3.20  2.50  2.30  3.20  2.75
# 3  6.50  1.50  3.75  5.50  1.44  3.75  6.50
# 4  1.65  4.50  3.50  1.65  4.75  3.30  1.67

# %%
match["TotalGoals"] = np.nan

# %%
match["TotalGoals"] = match["home_team_goal"] + match["away_team_goal"]

# %%
match["ShotonHome"] = np.nan
match["ShotonAway"] = np.nan

# %%
match["ShotonHome"] = match.apply(
    lambda x: extract_xml(x, "shoton", "team", "home"), axis=1
)
match["ShotonAway"] = match.apply(
    lambda x: extract_xml(x, "shoton", "team", "away"), axis=1
)

# %%
match["ShotoffHome"] = np.nan
match["ShotoffAway"] = np.nan

# %%
match["ShotoffHome"] = match.apply(
    lambda x: extract_xml(x, "shotoff", "team", "home"), axis=1
)
match["ShotoffAway"] = match.apply(
    lambda x: extract_xml(x, "shotoff", "team", "away"), axis=1
)

# %%
match["FoulCommitHome"] = np.nan
match["FoulCommitAway"] = np.nan

# %%
match["FoulCommitHome"] = match.apply(
    lambda x: extract_xml(x, "foulcommit", "team", "home"), axis=1
)
match["FoulCommitAway"] = match.apply(
    lambda x: extract_xml(x, "foulcommit", "team", "away"), axis=1
)

# %%
match["CardHome"] = np.nan
match["CardAway"] = np.nan

# %%
match["CardHome"] = match.apply(
    lambda x: extract_xml(x, "card", "team", "home"), axis=1
)
match["CardAway"] = match.apply(
    lambda x: extract_xml(x, "card", "team", "away"), axis=1
)

# %%
match["CrossHome"] = np.nan
match["CrossAway"] = np.nan

# %%
match["CrossHome"] = match.apply(
    lambda x: extract_xml(x, "cross", "team", "home"), axis=1
)
match["CrossAway"] = match.apply(
    lambda x: extract_xml(x, "cross", "team", "away"), axis=1
)

# %%
match["CornerHome"] = np.nan
match["CornerAway"] = np.nan

# %%
match["CornerHome"] = match.apply(
    lambda x: extract_xml(x, "corner", "team", "home"), axis=1
)
match["CornerAway"] = match.apply(
    lambda x: extract_xml(x, "corner", "team", "away"), axis=1
)

# %%
match["PossessionHome"] = np.nan
match["PossessionAway"] = np.nan

# %%
match["PossessionHome"] = match.apply(
    lambda x: extract_possession_xml(x, "possession", "homepos"), axis=1
)
match["PossessionAway"] = match.apply(
    lambda x: extract_possession_xml(x, "possession", "awaypos"), axis=1
)

# %%
match.drop(
    columns=["id", "stage", "country_id", "season"],
    inplace=True,
)

# %%
match.rename(
    columns={
        "league_id": "LeagueID",
        "match_api_id": "MatchID",
        "home_team_api_id": "HomeTeamID",
        "away_team_api_id": "AwayTeamID",
        "date": "Date",
        "home_team_goal": "HomeTeamGoal",
        "away_team_goal": "AwayTeamGoal",
        "home_player_1": "HomePlayer1",
        "home_player_2": "HomePlayer2",
        "home_player_3": "HomePlayer3",
        "home_player_4": "HomePlayer4",
        "home_player_5": "HomePlayer5",
        "home_player_6": "HomePlayer6",
        "home_player_7": "HomePlayer7",
        "home_player_8": "HomePlayer8",
        "home_player_9": "HomePlayer9",
        "home_player_10": "HomePlayer10",
        "home_player_11": "HomePlayer11",
        "away_player_1" :"AwayPlayer1",
        "away_player_2" :"AwayPlayer2",
        "away_player_3" :"AwayPlayer3",
        "away_player_4" :"AwayPlayer4",
        "away_player_5" :"AwayPlayer5",
        "away_player_6" :"AwayPlayer6",
        "away_player_7" :"AwayPlayer7",
        "away_player_8" :"AwayPlayer8",
        "away_player_9" :"AwayPlayer9",
        "away_player_10" :"AwayPlayer10",
        "away_player_11" :"AwayPlayer11",
        
    },
    inplace=True,
)

# %%
match.head()
# Out:
#    LeagueID                 Date  MatchID  HomeTeamID  AwayTeamID  \
# 0         1  2008-08-17 00:00:00   492473        9987        9993
# 1         1  2008-08-16 00:00:00   492474       10000        9994
# 2         1  2008-08-16 00:00:00   492475        9984        8635
# 3         1  2008-08-17 00:00:00   492476        9991        9998
# 4         1  2008-08-16 00:00:00   492477        7947        9985
#
#    HomeTeamGoal  AwayTeamGoal  home_player_X1  home_player_X2  home_player_X3  \
# 0             1             1             NaN             NaN             NaN
# 1             0             0             NaN             NaN             NaN
# 2             0             3             NaN             NaN             NaN
# 3             5             0             NaN             NaN             NaN
# 4             1             3             NaN             NaN             NaN
#
#    home_player_X4  home_player_X5  home_player_X6  home_player_X7  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    home_player_X8  home_player_X9  home_player_X10  home_player_X11  \
# 0             NaN             NaN              NaN              NaN
# 1             NaN             NaN              NaN              NaN
# 2             NaN             NaN              NaN              NaN
# 3             NaN             NaN              NaN              NaN
# 4             NaN             NaN              NaN              NaN
#
#    away_player_X1  away_player_X2  away_player_X3  away_player_X4  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    away_player_X5  away_player_X6  away_player_X7  away_player_X8  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    away_player_X9  away_player_X10  away_player_X11  home_player_Y1  \
# 0             NaN              NaN              NaN             NaN
# 1             NaN              NaN              NaN             NaN
# 2             NaN              NaN              NaN             NaN
# 3             NaN              NaN              NaN             NaN
# 4             NaN              NaN              NaN             NaN
#
#    home_player_Y2  home_player_Y3  home_player_Y4  home_player_Y5  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    home_player_Y6  home_player_Y7  home_player_Y8  home_player_Y9  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    home_player_Y10  home_player_Y11  away_player_Y1  away_player_Y2  \
# 0              NaN              NaN             NaN             NaN
# 1              NaN              NaN             NaN             NaN
# 2              NaN              NaN             NaN             NaN
# 3              NaN              NaN             NaN             NaN
# 4              NaN              NaN             NaN             NaN
#
#    away_player_Y3  away_player_Y4  away_player_Y5  away_player_Y6  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    away_player_Y7  away_player_Y8  away_player_Y9  away_player_Y10  \
# 0             NaN             NaN             NaN              NaN
# 1             NaN             NaN             NaN              NaN
# 2             NaN             NaN             NaN              NaN
# 3             NaN             NaN             NaN              NaN
# 4             NaN             NaN             NaN              NaN
#
#    away_player_Y11  HomePlayer1  HomePlayer2  HomePlayer3  HomePlayer4  \
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
#
#    HomePlayer5  HomePlayer6  HomePlayer7  HomePlayer8  HomePlayer9  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    HomePlayer10  HomePlayer11  AwayPlayer1  AwayPlayer2  AwayPlayer3  \
# 0           NaN           NaN          NaN          NaN          NaN
# 1           NaN           NaN          NaN          NaN          NaN
# 2           NaN           NaN          NaN          NaN          NaN
# 3           NaN           NaN          NaN          NaN          NaN
# 4           NaN           NaN          NaN          NaN          NaN
#
#    AwayPlayer4  AwayPlayer5  AwayPlayer6  AwayPlayer7  AwayPlayer8  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    AwayPlayer9  AwayPlayer10  AwayPlayer11  goal shoton shotoff foulcommit  \
# 0          NaN           NaN           NaN  None   None    None       None
# 1          NaN           NaN           NaN  None   None    None       None
# 2          NaN           NaN           NaN  None   None    None       None
# 3          NaN           NaN           NaN  None   None    None       None
# 4          NaN           NaN           NaN  None   None    None       None
#
#    card cross corner possession  B365H  B365D  B365A   BWH   BWD   BWA   IWH  \
# 0  None  None   None       None   1.73   3.40   5.00  1.75  3.35  4.20  1.85
# 1  None  None   None       None   1.95   3.20   3.60  1.80  3.30  3.95  1.90
# 2  None  None   None       None   2.38   3.30   2.75  2.40  3.30  2.55  2.60
# 3  None  None   None       None   1.44   3.75   7.50  1.40  4.00  6.80  1.40
# 4  None  None   None       None   5.00   3.50   1.65  5.00  3.50  1.60  4.00
#
#    IWD  IWA   LBH  LBD   LBA  PSH  PSD  PSA   WHH   WHD   WHA   SJH  SJD  \
# 0  3.2  3.5  1.80  3.3  3.75  NaN  NaN  NaN  1.70  3.30  4.33  1.90  3.3
# 1  3.2  3.5  1.90  3.2  3.50  NaN  NaN  NaN  1.83  3.30  3.60  1.95  3.3
# 2  3.1  2.3  2.50  3.2  2.50  NaN  NaN  NaN  2.50  3.25  2.40  2.63  3.3
# 3  3.9  6.0  1.44  3.6  6.50  NaN  NaN  NaN  1.44  3.75  6.00  1.44  4.0
# 4  3.3  1.7  4.00  3.4  1.72  NaN  NaN  NaN  4.20  3.40  1.70  4.50  3.5
#
#     SJA   VCH   VCD   VCA   GBH   GBD   GBA   BSH   BSD   BSA  TotalGoals  \
# 0  4.00  1.65  3.40  4.50  1.78  3.25  4.00  1.73  3.40  4.20           2
# 1  3.80  2.00  3.25  3.25  1.85  3.25  3.75  1.91  3.25  3.60           0
# 2  2.50  2.35  3.25  2.65  2.50  3.20  2.50  2.30  3.20  2.75           3
# 3  7.50  1.45  3.75  6.50  1.50  3.75  5.50  1.44  3.75  6.50           5
# 4  1.73  4.50  3.40  1.65  4.50  3.50  1.65  4.75  3.30  1.67           4
#
#    ShotonHome  ShotonAway  ShotoffHome  ShotoffAway  FoulCommitHome  \
# 0         NaN         NaN          NaN          NaN             NaN
# 1         NaN         NaN          NaN          NaN             NaN
# 2         NaN         NaN          NaN          NaN             NaN
# 3         NaN         NaN          NaN          NaN             NaN
# 4         NaN         NaN          NaN          NaN             NaN
#
#    FoulCommitAway  CardHome  CardAway  CrossHome  CrossAway  CornerHome  \
# 0             NaN       NaN       NaN        NaN        NaN         NaN
# 1             NaN       NaN       NaN        NaN        NaN         NaN
# 2             NaN       NaN       NaN        NaN        NaN         NaN
# 3             NaN       NaN       NaN        NaN        NaN         NaN
# 4             NaN       NaN       NaN        NaN        NaN         NaN
#
#    CornerAway  PossessionHome  PossessionAway
# 0         NaN             NaN             NaN
# 1         NaN             NaN             NaN
# 2         NaN             NaN             NaN
# 3         NaN             NaN             NaN
# 4         NaN             NaN             NaN

# %%
match.drop(match.iloc[:, 7:51], inplace = True, axis = 1)

# %%
match.head()
# Out:
#    LeagueID                 Date  MatchID  HomeTeamID  AwayTeamID  \
# 0         1  2008-08-17 00:00:00   492473        9987        9993
# 1         1  2008-08-16 00:00:00   492474       10000        9994
# 2         1  2008-08-16 00:00:00   492475        9984        8635
# 3         1  2008-08-17 00:00:00   492476        9991        9998
# 4         1  2008-08-16 00:00:00   492477        7947        9985
#
#    HomeTeamGoal  AwayTeamGoal  HomePlayer1  HomePlayer2  HomePlayer3  \
# 0             1             1          NaN          NaN          NaN
# 1             0             0          NaN          NaN          NaN
# 2             0             3          NaN          NaN          NaN
# 3             5             0          NaN          NaN          NaN
# 4             1             3          NaN          NaN          NaN
#
#    HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  HomePlayer8  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    HomePlayer9  HomePlayer10  HomePlayer11  AwayPlayer1  AwayPlayer2  \
# 0          NaN           NaN           NaN          NaN          NaN
# 1          NaN           NaN           NaN          NaN          NaN
# 2          NaN           NaN           NaN          NaN          NaN
# 3          NaN           NaN           NaN          NaN          NaN
# 4          NaN           NaN           NaN          NaN          NaN
#
#    AwayPlayer3  AwayPlayer4  AwayPlayer5  AwayPlayer6  AwayPlayer7  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    AwayPlayer8  AwayPlayer9  AwayPlayer10  AwayPlayer11  goal shoton shotoff  \
# 0          NaN          NaN           NaN           NaN  None   None    None
# 1          NaN          NaN           NaN           NaN  None   None    None
# 2          NaN          NaN           NaN           NaN  None   None    None
# 3          NaN          NaN           NaN           NaN  None   None    None
# 4          NaN          NaN           NaN           NaN  None   None    None
#
#   foulcommit  card cross corner possession  B365H  B365D  B365A   BWH   BWD  \
# 0       None  None  None   None       None   1.73   3.40   5.00  1.75  3.35
# 1       None  None  None   None       None   1.95   3.20   3.60  1.80  3.30
# 2       None  None  None   None       None   2.38   3.30   2.75  2.40  3.30
# 3       None  None  None   None       None   1.44   3.75   7.50  1.40  4.00
# 4       None  None  None   None       None   5.00   3.50   1.65  5.00  3.50
#
#     BWA   IWH  IWD  IWA   LBH  LBD   LBA  PSH  PSD  PSA   WHH   WHD   WHA  \
# 0  4.20  1.85  3.2  3.5  1.80  3.3  3.75  NaN  NaN  NaN  1.70  3.30  4.33
# 1  3.95  1.90  3.2  3.5  1.90  3.2  3.50  NaN  NaN  NaN  1.83  3.30  3.60
# 2  2.55  2.60  3.1  2.3  2.50  3.2  2.50  NaN  NaN  NaN  2.50  3.25  2.40
# 3  6.80  1.40  3.9  6.0  1.44  3.6  6.50  NaN  NaN  NaN  1.44  3.75  6.00
# 4  1.60  4.00  3.3  1.7  4.00  3.4  1.72  NaN  NaN  NaN  4.20  3.40  1.70
#
#     SJH  SJD   SJA   VCH   VCD   VCA   GBH   GBD   GBA   BSH   BSD   BSA  \
# 0  1.90  3.3  4.00  1.65  3.40  4.50  1.78  3.25  4.00  1.73  3.40  4.20
# 1  1.95  3.3  3.80  2.00  3.25  3.25  1.85  3.25  3.75  1.91  3.25  3.60
# 2  2.63  3.3  2.50  2.35  3.25  2.65  2.50  3.20  2.50  2.30  3.20  2.75
# 3  1.44  4.0  7.50  1.45  3.75  6.50  1.50  3.75  5.50  1.44  3.75  6.50
# 4  4.50  3.5  1.73  4.50  3.40  1.65  4.50  3.50  1.65  4.75  3.30  1.67
#
#    TotalGoals  ShotonHome  ShotonAway  ShotoffHome  ShotoffAway  \
# 0           2         NaN         NaN          NaN          NaN
# 1           0         NaN         NaN          NaN          NaN
# 2           3         NaN         NaN          NaN          NaN
# 3           5         NaN         NaN          NaN          NaN
# 4           4         NaN         NaN          NaN          NaN
#
#    FoulCommitHome  FoulCommitAway  CardHome  CardAway  CrossHome  CrossAway  \
# 0             NaN             NaN       NaN       NaN        NaN        NaN
# 1             NaN             NaN       NaN       NaN        NaN        NaN
# 2             NaN             NaN       NaN       NaN        NaN        NaN
# 3             NaN             NaN       NaN       NaN        NaN        NaN
# 4             NaN             NaN       NaN       NaN        NaN        NaN
#
#    CornerHome  CornerAway  PossessionHome  PossessionAway
# 0         NaN         NaN             NaN             NaN
# 1         NaN         NaN             NaN             NaN
# 2         NaN         NaN             NaN             NaN
# 3         NaN         NaN             NaN             NaN
# 4         NaN         NaN             NaN             NaN

# %%
match.drop(match.iloc[:, 29:67], inplace = True, axis = 1)

# %%
match.head()
# Out:
#    LeagueID                 Date  MatchID  HomeTeamID  AwayTeamID  \
# 0         1  2008-08-17 00:00:00   492473        9987        9993
# 1         1  2008-08-16 00:00:00   492474       10000        9994
# 2         1  2008-08-16 00:00:00   492475        9984        8635
# 3         1  2008-08-17 00:00:00   492476        9991        9998
# 4         1  2008-08-16 00:00:00   492477        7947        9985
#
#    HomeTeamGoal  AwayTeamGoal  HomePlayer1  HomePlayer2  HomePlayer3  \
# 0             1             1          NaN          NaN          NaN
# 1             0             0          NaN          NaN          NaN
# 2             0             3          NaN          NaN          NaN
# 3             5             0          NaN          NaN          NaN
# 4             1             3          NaN          NaN          NaN
#
#    HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  HomePlayer8  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    HomePlayer9  HomePlayer10  HomePlayer11  AwayPlayer1  AwayPlayer2  \
# 0          NaN           NaN           NaN          NaN          NaN
# 1          NaN           NaN           NaN          NaN          NaN
# 2          NaN           NaN           NaN          NaN          NaN
# 3          NaN           NaN           NaN          NaN          NaN
# 4          NaN           NaN           NaN          NaN          NaN
#
#    AwayPlayer3  AwayPlayer4  AwayPlayer5  AwayPlayer6  AwayPlayer7  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    AwayPlayer8  AwayPlayer9  AwayPlayer10  AwayPlayer11  TotalGoals  \
# 0          NaN          NaN           NaN           NaN           2
# 1          NaN          NaN           NaN           NaN           0
# 2          NaN          NaN           NaN           NaN           3
# 3          NaN          NaN           NaN           NaN           5
# 4          NaN          NaN           NaN           NaN           4
#
#    ShotonHome  ShotonAway  ShotoffHome  ShotoffAway  FoulCommitHome  \
# 0         NaN         NaN          NaN          NaN             NaN
# 1         NaN         NaN          NaN          NaN             NaN
# 2         NaN         NaN          NaN          NaN             NaN
# 3         NaN         NaN          NaN          NaN             NaN
# 4         NaN         NaN          NaN          NaN             NaN
#
#    FoulCommitAway  CardHome  CardAway  CrossHome  CrossAway  CornerHome  \
# 0             NaN       NaN       NaN        NaN        NaN         NaN
# 1             NaN       NaN       NaN        NaN        NaN         NaN
# 2             NaN       NaN       NaN        NaN        NaN         NaN
# 3             NaN       NaN       NaN        NaN        NaN         NaN
# 4             NaN       NaN       NaN        NaN        NaN         NaN
#
#    CornerAway  PossessionHome  PossessionAway
# 0         NaN             NaN             NaN
# 1         NaN             NaN             NaN
# 2         NaN             NaN             NaN
# 3         NaN             NaN             NaN
# 4         NaN             NaN             NaN

# %%
match["Date"] = pd.DatetimeIndex(match["Date"]).year

# %%
matches = pd.merge(league, match, on="LeagueID", how="inner")

# %%
matches.head()
# Out:
#    LeagueID              LeagueName  Date  MatchID  HomeTeamID  AwayTeamID  \
# 0         1  Belgium Jupiler League  2008   492473        9987        9993
# 1         1  Belgium Jupiler League  2008   492474       10000        9994
# 2         1  Belgium Jupiler League  2008   492475        9984        8635
# 3         1  Belgium Jupiler League  2008   492476        9991        9998
# 4         1  Belgium Jupiler League  2008   492477        7947        9985
#
#    HomeTeamGoal  AwayTeamGoal  HomePlayer1  HomePlayer2  HomePlayer3  \
# 0             1             1          NaN          NaN          NaN
# 1             0             0          NaN          NaN          NaN
# 2             0             3          NaN          NaN          NaN
# 3             5             0          NaN          NaN          NaN
# 4             1             3          NaN          NaN          NaN
#
#    HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  HomePlayer8  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    HomePlayer9  HomePlayer10  HomePlayer11  AwayPlayer1  AwayPlayer2  \
# 0          NaN           NaN           NaN          NaN          NaN
# 1          NaN           NaN           NaN          NaN          NaN
# 2          NaN           NaN           NaN          NaN          NaN
# 3          NaN           NaN           NaN          NaN          NaN
# 4          NaN           NaN           NaN          NaN          NaN
#
#    AwayPlayer3  AwayPlayer4  AwayPlayer5  AwayPlayer6  AwayPlayer7  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    AwayPlayer8  AwayPlayer9  AwayPlayer10  AwayPlayer11  TotalGoals  \
# 0          NaN          NaN           NaN           NaN           2
# 1          NaN          NaN           NaN           NaN           0
# 2          NaN          NaN           NaN           NaN           3
# 3          NaN          NaN           NaN           NaN           5
# 4          NaN          NaN           NaN           NaN           4
#
#    ShotonHome  ShotonAway  ShotoffHome  ShotoffAway  FoulCommitHome  \
# 0         NaN         NaN          NaN          NaN             NaN
# 1         NaN         NaN          NaN          NaN             NaN
# 2         NaN         NaN          NaN          NaN             NaN
# 3         NaN         NaN          NaN          NaN             NaN
# 4         NaN         NaN          NaN          NaN             NaN
#
#    FoulCommitAway  CardHome  CardAway  CrossHome  CrossAway  CornerHome  \
# 0             NaN       NaN       NaN        NaN        NaN         NaN
# 1             NaN       NaN       NaN        NaN        NaN         NaN
# 2             NaN       NaN       NaN        NaN        NaN         NaN
# 3             NaN       NaN       NaN        NaN        NaN         NaN
# 4             NaN       NaN       NaN        NaN        NaN         NaN
#
#    CornerAway  PossessionHome  PossessionAway
# 0         NaN             NaN             NaN
# 1         NaN             NaN             NaN
# 2         NaN             NaN             NaN
# 3         NaN             NaN             NaN
# 4         NaN             NaN             NaN

# %%
total_goals = matches.pop('TotalGoals')
matches.insert(8, 'Total', total_goals)

# %%
matches.head()
# Out:
#    LeagueID              LeagueName  Date  MatchID  HomeTeamID  AwayTeamID  \
# 0         1  Belgium Jupiler League  2008   492473        9987        9993
# 1         1  Belgium Jupiler League  2008   492474       10000        9994
# 2         1  Belgium Jupiler League  2008   492475        9984        8635
# 3         1  Belgium Jupiler League  2008   492476        9991        9998
# 4         1  Belgium Jupiler League  2008   492477        7947        9985
#
#    HomeTeamGoal  AwayTeamGoal  Total  HomePlayer1  HomePlayer2  HomePlayer3  \
# 0             1             1      2          NaN          NaN          NaN
# 1             0             0      0          NaN          NaN          NaN
# 2             0             3      3          NaN          NaN          NaN
# 3             5             0      5          NaN          NaN          NaN
# 4             1             3      4          NaN          NaN          NaN
#
#    HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  HomePlayer8  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    HomePlayer9  HomePlayer10  HomePlayer11  AwayPlayer1  AwayPlayer2  \
# 0          NaN           NaN           NaN          NaN          NaN
# 1          NaN           NaN           NaN          NaN          NaN
# 2          NaN           NaN           NaN          NaN          NaN
# 3          NaN           NaN           NaN          NaN          NaN
# 4          NaN           NaN           NaN          NaN          NaN
#
#    AwayPlayer3  AwayPlayer4  AwayPlayer5  AwayPlayer6  AwayPlayer7  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    AwayPlayer8  AwayPlayer9  AwayPlayer10  AwayPlayer11  ShotonHome  \
# 0          NaN          NaN           NaN           NaN         NaN
# 1          NaN          NaN           NaN           NaN         NaN
# 2          NaN          NaN           NaN           NaN         NaN
# 3          NaN          NaN           NaN           NaN         NaN
# 4          NaN          NaN           NaN           NaN         NaN
#
#    ShotonAway  ShotoffHome  ShotoffAway  FoulCommitHome  FoulCommitAway  \
# 0         NaN          NaN          NaN             NaN             NaN
# 1         NaN          NaN          NaN             NaN             NaN
# 2         NaN          NaN          NaN             NaN             NaN
# 3         NaN          NaN          NaN             NaN             NaN
# 4         NaN          NaN          NaN             NaN             NaN
#
#    CardHome  CardAway  CrossHome  CrossAway  CornerHome  CornerAway  \
# 0       NaN       NaN        NaN        NaN         NaN         NaN
# 1       NaN       NaN        NaN        NaN         NaN         NaN
# 2       NaN       NaN        NaN        NaN         NaN         NaN
# 3       NaN       NaN        NaN        NaN         NaN         NaN
# 4       NaN       NaN        NaN        NaN         NaN         NaN
#
#    PossessionHome  PossessionAway
# 0             NaN             NaN
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN

# %%
matches.shape
# Out:
# (25979, 45)

# %%
matches.to_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches.csv",
    index=True,
    header=True,
    encoding="utf-8",
)

# %%
matches = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches.csv",
    index_col=0,
)

# %%
matches.head()
# Out:
#    LeagueID              LeagueName  Date  MatchID  HomeTeamID  AwayTeamID  \
# 0         1  Belgium Jupiler League  2008   492473        9987        9993
# 1         1  Belgium Jupiler League  2008   492474       10000        9994
# 2         1  Belgium Jupiler League  2008   492475        9984        8635
# 3         1  Belgium Jupiler League  2008   492476        9991        9998
# 4         1  Belgium Jupiler League  2008   492477        7947        9985
#
#    HomeTeamGoal  AwayTeamGoal  Total  HomePlayer1  HomePlayer2  HomePlayer3  \
# 0             1             1      2          NaN          NaN          NaN
# 1             0             0      0          NaN          NaN          NaN
# 2             0             3      3          NaN          NaN          NaN
# 3             5             0      5          NaN          NaN          NaN
# 4             1             3      4          NaN          NaN          NaN
#
#    HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  HomePlayer8  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    HomePlayer9  HomePlayer10  HomePlayer11  AwayPlayer1  AwayPlayer2  \
# 0          NaN           NaN           NaN          NaN          NaN
# 1          NaN           NaN           NaN          NaN          NaN
# 2          NaN           NaN           NaN          NaN          NaN
# 3          NaN           NaN           NaN          NaN          NaN
# 4          NaN           NaN           NaN          NaN          NaN
#
#    AwayPlayer3  AwayPlayer4  AwayPlayer5  AwayPlayer6  AwayPlayer7  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    AwayPlayer8  AwayPlayer9  AwayPlayer10  AwayPlayer11  ShotonHome  \
# 0          NaN          NaN           NaN           NaN         NaN
# 1          NaN          NaN           NaN           NaN         NaN
# 2          NaN          NaN           NaN           NaN         NaN
# 3          NaN          NaN           NaN           NaN         NaN
# 4          NaN          NaN           NaN           NaN         NaN
#
#    ShotonAway  ShotoffHome  ShotoffAway  FoulCommitHome  FoulCommitAway  \
# 0         NaN          NaN          NaN             NaN             NaN
# 1         NaN          NaN          NaN             NaN             NaN
# 2         NaN          NaN          NaN             NaN             NaN
# 3         NaN          NaN          NaN             NaN             NaN
# 4         NaN          NaN          NaN             NaN             NaN
#
#    CardHome  CardAway  CrossHome  CrossAway  CornerHome  CornerAway  \
# 0       NaN       NaN        NaN        NaN         NaN         NaN
# 1       NaN       NaN        NaN        NaN         NaN         NaN
# 2       NaN       NaN        NaN        NaN         NaN         NaN
# 3       NaN       NaN        NaN        NaN         NaN         NaN
# 4       NaN       NaN        NaN        NaN         NaN         NaN
#
#    PossessionHome  PossessionAway
# 0             NaN             NaN
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN

# %%
matches.shape
# Out:
# (25979, 45)
