# %% [markdown]
# ## Display Features

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings

from xml.etree.ElementTree import fromstring, ElementTree
import xml.etree.ElementTree as ET

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

# %% [markdown]
# # Load Datasets

# %% [markdown]
# ## Players

# %%
players = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\players.csv",
    index_col=0,
)

# %%
overall_rating = players[["Date", "PlayerID", "OverallRating"]]

# %% [markdown]
# ## Matches

# %%
matches = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches.csv",
    index_col=0,
)

# %%
matches.isna().sum()
# Out:
# LeagueID                          0
# LeagueName                        0
# Date                              0
# MatchID                           0
# HomeTeamID                        0
# AwayTeamID                        0
# HomeGoal                          0
# AwayGoal                          0
# HomePlayer1                     263
# HomePlayer2                     299
# HomePlayer3                     289
# HomePlayer4                     324
# HomePlayer5                     304
# HomePlayer6                     305
# HomePlayer7                     262
# HomePlayer8                     284
# HomePlayer9                     279
# HomePlayer10                    387
# HomePlayer11                    485
# AwayPlayer1                     273
# AwayPlayer2                     264
# AwayPlayer3                     320
# AwayPlayer4                     308
# AwayPlayer5                     320
# AwayPlayer6                     297
# AwayPlayer7                     272
# AwayPlayer8                     324
# AwayPlayer9                     313
# AwayPlayer10                    390
# AwayPlayer11                    483
# TotalGoals                        0
# HomeShoton                     7408
# AwayShoton                     7408
# HomeShotoff                    7408
# AwayShotoff                    7408
# HomeFoulCommit                 7408
# AwayFoulCommit                 7408
# HomeCard                       7408
# AwayCard                       7408
# HomeCross                      7408
# AwayCross                      7408
# HomeCorner                     7408
# AwayCorner                     7408
# HomePossession                12144
# AwayPossession                12144
# HomeTeamID.1                      0
# HomeTeamLongName                  0
# HomeTeamShortName                 0
# HomeBuildUpPlaySpeed              0
# HomeBuildUpPlayPassing            0
# HomeChanceCreationPassing         0
# HomeChanceCreationCrossing        0
# HomeChanceCreationShooting        0
# HomeDefencePressure               0
# HomeDefenceAggression             0
# HomeDefenceTeamWidth              0
# AwayTeamID.1                      0
# AwayTeamLongName                  0
# AwayTeamShortName                 0
# AwayBuildUpPlaySpeed              0
# AwayBuildUpPlayPassing            0
# AwayChanceCreationPassing         0
# AwayChanceCreationCrossing        0
# AwayChanceCreationShooting        0
# AwayDefencePressure               0
# AwayDefenceAggression             0
# AwayDefenceTeamWidth              0
# dtype: int64

# %%
def overall_function(player, date, player_id, rating_column, left_dataframe, right_dataframe):

    df_merge = pd.merge(left_dataframe, right_dataframe, left_on=[date, player_id], right_on=[date, player], how='right')
    df_merge[player] = df_merge[rating_column]
    del df_merge[rating_column]
    del df_merge[player_id]

    return df_merge

# %%
player = "HomePlayer1"
date = "Date"
player_id = "PlayerID"
rating_column = "OverallRating"
left_dataframe = overall_rating
right_dataframe = matches


df_merge = overall_function(player, date, player_id, rating_column, left_dataframe, right_dataframe)

# %%
df_merge.head()
# Out:
#    Date  LeagueID              LeagueName  MatchID  HomeTeamID  AwayTeamID  \
# 0  2010         1  Belgium Jupiler League   665626        8635        8342
# 1  2010         1  Belgium Jupiler League   838635        8635        8342
# 2  2010         1  Belgium Jupiler League   838544        9986        8342
# 3  2010         1  Belgium Jupiler League   838714        8203        8342
# 4  2010         1  Belgium Jupiler League   665737        9997        8342
#
#    HomeGoal  AwayGoal  HomePlayer1  HomePlayer2  HomePlayer3  HomePlayer4  \
# 0         3         2         72.0      33620.0      38388.0      38389.0
# 1         2         2         72.0      38389.0      38253.0      69713.0
# 2         0         5         55.0      39977.0      93054.0      46666.0
# 3         0         1         69.5      67950.0      39389.0      80184.0
# 4         1         1         68.5      33595.0      37866.0       3329.0
#
#    HomePlayer5  HomePlayer6  HomePlayer7  HomePlayer8  HomePlayer9  \
# 0      38253.0      69713.0      38393.0     148302.0      38378.0
# 1      94553.0      38378.0      69653.0     148302.0      12692.0
# 2      93344.0      39145.0      26613.0      45469.0      40520.0
# 3      67941.0      37112.0      38969.0     178291.0      67957.0
# 4     149150.0      38354.0     178486.0      36836.0      45490.0
#
#    HomePlayer10  HomePlayer11  AwayPlayer1  AwayPlayer2  AwayPlayer3  \
# 0       38383.0      181276.0      37990.0      36832.0      21812.0
# 1       46552.0      181276.0      31226.0      36832.0      27508.0
# 2           NaN       38732.0      31226.0      36832.0      39578.0
# 3      148286.0      148315.0      37990.0      36832.0      27508.0
# 4       68120.0        5016.0      37990.0      36832.0      21812.0
#
#    AwayPlayer4  AwayPlayer5  AwayPlayer6  AwayPlayer7  AwayPlayer8  \
# 0      38336.0      39578.0      37979.0      11736.0      42594.0
# 1      39878.0      47411.0      39578.0      38366.0      52280.0
# 2      42594.0      47411.0      35412.0      51841.0      38336.0
# 3      39878.0      42594.0      39578.0      38336.0      38366.0
# 4      11736.0      42594.0      39578.0      37979.0      38366.0
#
#    AwayPlayer9  AwayPlayer10  AwayPlayer11  TotalGoals  HomeShoton  \
# 0      38366.0      163670.0       75405.0           5         NaN
# 1      35412.0      163670.0       75405.0           4         NaN
# 2      52280.0       38366.0      163670.0           5         NaN
# 3     163670.0       52280.0       38440.0           1         NaN
# 4     163670.0       27423.0       38440.0           2         NaN
#
#    AwayShoton  HomeShotoff  AwayShotoff  HomeFoulCommit  AwayFoulCommit  \
# 0         NaN          NaN          NaN             NaN             NaN
# 1         NaN          NaN          NaN             NaN             NaN
# 2         NaN          NaN          NaN             NaN             NaN
# 3         NaN          NaN          NaN             NaN             NaN
# 4         NaN          NaN          NaN             NaN             NaN
#
#    HomeCard  AwayCard  HomeCross  AwayCross  HomeCorner  AwayCorner  \
# 0       NaN       NaN        NaN        NaN         NaN         NaN
# 1       NaN       NaN        NaN        NaN         NaN         NaN
# 2       NaN       NaN        NaN        NaN         NaN         NaN
# 3       NaN       NaN        NaN        NaN         NaN         NaN
# 4       NaN       NaN        NaN        NaN         NaN         NaN
#
#    HomePossession  AwayPossession  HomeTeamID.1    HomeTeamLongName  \
# 0             NaN             NaN          8635      RSC Anderlecht
# 1             NaN             NaN          8635      RSC Anderlecht
# 2             NaN             NaN          9986  Sporting Charleroi
# 3             NaN             NaN          8203         KV Mechelen
# 4             NaN             NaN          9997   Sint-Truidense VV
#
#   HomeTeamShortName  HomeBuildUpPlaySpeed  HomeBuildUpPlayPassing  \
# 0               AND                    50                      35
# 1               AND                    50                      35
# 2               CHA                    40                      50
# 3               MEC                    65                      60
# 4               STT                    50                      50
#
#    HomeChanceCreationPassing  HomeChanceCreationCrossing  \
# 0                         70                          50
# 1                         70                          50
# 2                         45                          43
# 3                         50                          40
# 4                         50                          50
#
#    HomeChanceCreationShooting  HomeDefencePressure  HomeDefenceAggression  \
# 0                          60                   70                     50
# 1                          60                   70                     50
# 2                          60                   70                     70
# 3                          50                   60                     70
# 4                          50                   50                     50
#
#    HomeDefenceTeamWidth  AwayTeamID.1 AwayTeamLongName AwayTeamShortName  \
# 0                    70          8342   Club Brugge KV               CLB
# 1                    70          8342   Club Brugge KV               CLB
# 2                    70          8342   Club Brugge KV               CLB
# 3                    60          8342   Club Brugge KV               CLB
# 4                    50          8342   Club Brugge KV               CLB
#
#    AwayBuildUpPlaySpeed  AwayBuildUpPlayPassing  AwayChanceCreationPassing  \
# 0                    35                      40                         45
# 1                    35                      40                         45
# 2                    35                      40                         45
# 3                    35                      40                         45
# 4                    35                      40                         45
#
#    AwayChanceCreationCrossing  AwayChanceCreationShooting  \
# 0                          50                          45
# 1                          50                          45
# 2                          50                          45
# 3                          50                          45
# 4                          50                          45
#
#    AwayDefencePressure  AwayDefenceAggression  AwayDefenceTeamWidth
# 0                   60                     70                    70
# 1                   60                     70                    70
# 2                   60                     70                    70
# 3                   60                     70                    70
# 4                   60                     70                    70

# %%
df_merge.shape
# Out:
# (18243, 67)

# %%
df_merge.isna().sum()
# Out:
# Date                              0
# LeagueID                          0
# LeagueName                        0
# MatchID                           0
# HomeTeamID                        0
# AwayTeamID                        0
# HomeGoal                          0
# AwayGoal                          0
# HomePlayer1                     411
# HomePlayer2                     299
# HomePlayer3                     289
# HomePlayer4                     324
# HomePlayer5                     304
# HomePlayer6                     305
# HomePlayer7                     262
# HomePlayer8                     284
# HomePlayer9                     279
# HomePlayer10                    387
# HomePlayer11                    485
# AwayPlayer1                     273
# AwayPlayer2                     264
# AwayPlayer3                     320
# AwayPlayer4                     308
# AwayPlayer5                     320
# AwayPlayer6                     297
# AwayPlayer7                     272
# AwayPlayer8                     324
# AwayPlayer9                     313
# AwayPlayer10                    390
# AwayPlayer11                    483
# TotalGoals                        0
# HomeShoton                     7408
# AwayShoton                     7408
# HomeShotoff                    7408
# AwayShotoff                    7408
# HomeFoulCommit                 7408
# AwayFoulCommit                 7408
# HomeCard                       7408
# AwayCard                       7408
# HomeCross                      7408
# AwayCross                      7408
# HomeCorner                     7408
# AwayCorner                     7408
# HomePossession                12144
# AwayPossession                12144
# HomeTeamID.1                      0
# HomeTeamLongName                  0
# HomeTeamShortName                 0
# HomeBuildUpPlaySpeed              0
# HomeBuildUpPlayPassing            0
# HomeChanceCreationPassing         0
# HomeChanceCreationCrossing        0
# HomeChanceCreationShooting        0
# HomeDefencePressure               0
# HomeDefenceAggression             0
# HomeDefenceTeamWidth              0
# AwayTeamID.1                      0
# AwayTeamLongName                  0
# AwayTeamShortName                 0
# AwayBuildUpPlaySpeed              0
# AwayBuildUpPlayPassing            0
# AwayChanceCreationPassing         0
# AwayChanceCreationCrossing        0
# AwayChanceCreationShooting        0
# AwayDefencePressure               0
# AwayDefenceAggression             0
# AwayDefenceTeamWidth              0
# dtype: int64

# %%
player = "HomePlayer2"
date = "Date"
player_id = "PlayerID"
rating_column = "OverallRating"
left_dataframe = overall_rating
right_dataframe = df_merge


df_merge = overall_function(player, date, player_id, rating_column, left_dataframe, right_dataframe)

# %%
df_merge.sort_values("Date").head()
# Out:
#        Date  LeagueID              LeagueName  MatchID  HomeTeamID  \
# 0      2010         1  Belgium Jupiler League   665626        8635
# 11276  2010     15722      Poland Ekstraklasa   838608        2183
# 11277  2010     15722      Poland Ekstraklasa   674856        8028
# 11278  2010     15722      Poland Ekstraklasa   674870        8673
# 11279  2010     15722      Poland Ekstraklasa   838509        2182
#
#        AwayTeamID  HomeGoal  AwayGoal  HomePlayer1  HomePlayer2  HomePlayer3  \
# 0            8342         3         2         72.0         72.5      38388.0
# 11276       10265         0         1         65.0         56.5      68744.0
# 11277       10265         1         4          NaN          NaN     150670.0
# 11278       10265         0         3         74.0         63.0          NaN
# 11279       10265         4         1         59.0         56.0      74827.0
#
#        HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  HomePlayer8  \
# 0          38389.0      38253.0      69713.0      38393.0     148302.0
# 11276          NaN      13551.0      69485.0      13449.0      74744.0
# 11277          NaN          NaN          NaN      13410.0          NaN
# 11278      72543.0          NaN          NaN          NaN     112656.0
# 11279          NaN     114827.0      78413.0      39798.0      13428.0
#
#        HomePlayer9  HomePlayer10  HomePlayer11  AwayPlayer1  AwayPlayer2  \
# 0          38378.0       38383.0      181276.0      37990.0      36832.0
# 11276          NaN           NaN       69008.0      43313.0      72441.0
# 11277      69628.0      105535.0        4999.0          NaN          NaN
# 11278          NaN       69346.0           NaN          NaN          NaN
# 11279     138171.0       79747.0       79982.0      43313.0      72441.0
#
#        AwayPlayer3  AwayPlayer4  AwayPlayer5  AwayPlayer6  AwayPlayer7  \
# 0          21812.0      38336.0      39578.0      37979.0      11736.0
# 11276     198855.0      72767.0      29318.0      30976.0      69554.0
# 11277      78908.0      39070.0      51841.0          NaN          NaN
# 11278      39070.0      78908.0      51841.0      69554.0          NaN
# 11279          NaN     198855.0      29318.0      92375.0      30976.0
#
#        AwayPlayer8  AwayPlayer9  AwayPlayer10  AwayPlayer11  TotalGoals  \
# 0          42594.0      38366.0      163670.0       75405.0           5
# 11276          NaN      39069.0       72633.0       30978.0           1
# 11277      30976.0      69554.0       68766.0       30978.0           5
# 11278      30976.0      43321.0       68766.0       30978.0           3
# 11279      69554.0      33436.0       72633.0       30978.0           5
#
#        HomeShoton  AwayShoton  HomeShotoff  AwayShotoff  HomeFoulCommit  \
# 0             NaN         NaN          NaN          NaN             NaN
# 11276         NaN         NaN          NaN          NaN             NaN
# 11277         NaN         NaN          NaN          NaN             NaN
# 11278         NaN         NaN          NaN          NaN             NaN
# 11279         NaN         NaN          NaN          NaN             NaN
#
#        AwayFoulCommit  HomeCard  AwayCard  HomeCross  AwayCross  HomeCorner  \
# 0                 NaN       NaN       NaN        NaN        NaN         NaN
# 11276             NaN       NaN       NaN        NaN        NaN         NaN
# 11277             NaN       NaN       NaN        NaN        NaN         NaN
# 11278             NaN       NaN       NaN        NaN        NaN         NaN
# 11279             NaN       NaN       NaN        NaN        NaN         NaN
#
#        AwayCorner  HomePossession  AwayPossession  HomeTeamID.1  \
# 0             NaN             NaN             NaN          8635
# 11276         NaN             NaN             NaN          2183
# 11277         NaN             NaN             NaN          8028
# 11278         NaN             NaN             NaN          8673
# 11279         NaN             NaN             NaN          2182
#
#       HomeTeamLongName HomeTeamShortName  HomeBuildUpPlaySpeed  \
# 0       RSC Anderlecht               AND                    50
# 11276      P. Warszawa               PWA                    30
# 11277    Piast Gliwice               PIG                    30
# 11278   Legia Warszawa               LEG                    30
# 11279      Lech Poznań               POZ                    40
#
#        HomeBuildUpPlayPassing  HomeChanceCreationPassing  \
# 0                          35                         70
# 11276                      40                         45
# 11277                      45                         45
# 11278                      35                         55
# 11279                      35                         45
#
#        HomeChanceCreationCrossing  HomeChanceCreationShooting  \
# 0                              50                          60
# 11276                          40                          70
# 11277                          35                          70
# 11278                          45                          70
# 11279                          40                          70
#
#        HomeDefencePressure  HomeDefenceAggression  HomeDefenceTeamWidth  \
# 0                       70                     50                    70
# 11276                   55                     65                    55
# 11277                   65                     70                    60
# 11278                   65                     70                    60
# 11279                   60                     55                    45
#
#        AwayTeamID.1 AwayTeamLongName AwayTeamShortName  AwayBuildUpPlaySpeed  \
# 0              8342   Club Brugge KV               CLB                    35
# 11276         10265     Wisła Kraków               WIS                    40
# 11277         10265     Wisła Kraków               WIS                    40
# 11278         10265     Wisła Kraków               WIS                    40
# 11279         10265     Wisła Kraków               WIS                    40
#
#        AwayBuildUpPlayPassing  AwayChanceCreationPassing  \
# 0                          40                         45
# 11276                      35                         55
# 11277                      35                         55
# 11278                      35                         55
# 11279                      35                         55
#
#        AwayChanceCreationCrossing  AwayChanceCreationShooting  \
# 0                              50                          45
# 11276                          35                          70
# 11277                          35                          70
# 11278                          35                          70
# 11279                          35                          70
#
#        AwayDefencePressure  AwayDefenceAggression  AwayDefenceTeamWidth
# 0                       60                     70                    70
# 11276                   70                     70                    65
# 11277                   70                     70                    65
# 11278                   70                     70                    65
# 11279                   70                     70                    65

# %%
df_merge.shape
# Out:
# (18243, 67)

# %%
df_merge.isna().sum()
# Out:
# Date                              0
# LeagueID                          0
# LeagueName                        0
# MatchID                           0
# HomeTeamID                        0
# AwayTeamID                        0
# HomeGoal                          0
# AwayGoal                          0
# HomePlayer1                     411
# HomePlayer2                     579
# HomePlayer3                     289
# HomePlayer4                     324
# HomePlayer5                     304
# HomePlayer6                     305
# HomePlayer7                     262
# HomePlayer8                     284
# HomePlayer9                     279
# HomePlayer10                    387
# HomePlayer11                    485
# AwayPlayer1                     273
# AwayPlayer2                     264
# AwayPlayer3                     320
# AwayPlayer4                     308
# AwayPlayer5                     320
# AwayPlayer6                     297
# AwayPlayer7                     272
# AwayPlayer8                     324
# AwayPlayer9                     313
# AwayPlayer10                    390
# AwayPlayer11                    483
# TotalGoals                        0
# HomeShoton                     7408
# AwayShoton                     7408
# HomeShotoff                    7408
# AwayShotoff                    7408
# HomeFoulCommit                 7408
# AwayFoulCommit                 7408
# HomeCard                       7408
# AwayCard                       7408
# HomeCross                      7408
# AwayCross                      7408
# HomeCorner                     7408
# AwayCorner                     7408
# HomePossession                12144
# AwayPossession                12144
# HomeTeamID.1                      0
# HomeTeamLongName                  0
# HomeTeamShortName                 0
# HomeBuildUpPlaySpeed              0
# HomeBuildUpPlayPassing            0
# HomeChanceCreationPassing         0
# HomeChanceCreationCrossing        0
# HomeChanceCreationShooting        0
# HomeDefencePressure               0
# HomeDefenceAggression             0
# HomeDefenceTeamWidth              0
# AwayTeamID.1                      0
# AwayTeamLongName                  0
# AwayTeamShortName                 0
# AwayBuildUpPlaySpeed              0
# AwayBuildUpPlayPassing            0
# AwayChanceCreationPassing         0
# AwayChanceCreationCrossing        0
# AwayChanceCreationShooting        0
# AwayDefencePressure               0
# AwayDefenceAggression             0
# AwayDefenceTeamWidth              0
# dtype: int64

# %%
player = "HomePlayer3"
date = "Date"
player_id = "PlayerID"
rating_column = "OverallRating"
left_dataframe = overall_rating
right_dataframe = df_merge


df_merge = overall_function(player, date, player_id, rating_column, left_dataframe, right_dataframe)

# %%
df_merge.sort_values("Date").head()
# Out:
#        Date  LeagueID              LeagueName  MatchID  HomeTeamID  \
# 0      2010         1  Belgium Jupiler League   665626        8635
# 11276  2010     15722      Poland Ekstraklasa   838608        2183
# 11277  2010     15722      Poland Ekstraklasa   674856        8028
# 11278  2010     15722      Poland Ekstraklasa   674870        8673
# 11279  2010     15722      Poland Ekstraklasa   838509        2182
#
#        AwayTeamID  HomeGoal  AwayGoal  HomePlayer1  HomePlayer2  HomePlayer3  \
# 0            8342         3         2         72.0         72.5         72.0
# 11276       10265         0         1         65.0         56.5         68.0
# 11277       10265         1         4          NaN          NaN         67.0
# 11278       10265         0         3         74.0         63.0          NaN
# 11279       10265         4         1         59.0         56.0         74.0
#
#        HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  HomePlayer8  \
# 0          38389.0      38253.0      69713.0      38393.0     148302.0
# 11276          NaN      13551.0      69485.0      13449.0      74744.0
# 11277          NaN          NaN          NaN      13410.0          NaN
# 11278      72543.0          NaN          NaN          NaN     112656.0
# 11279          NaN     114827.0      78413.0      39798.0      13428.0
#
#        HomePlayer9  HomePlayer10  HomePlayer11  AwayPlayer1  AwayPlayer2  \
# 0          38378.0       38383.0      181276.0      37990.0      36832.0
# 11276          NaN           NaN       69008.0      43313.0      72441.0
# 11277      69628.0      105535.0        4999.0          NaN          NaN
# 11278          NaN       69346.0           NaN          NaN          NaN
# 11279     138171.0       79747.0       79982.0      43313.0      72441.0
#
#        AwayPlayer3  AwayPlayer4  AwayPlayer5  AwayPlayer6  AwayPlayer7  \
# 0          21812.0      38336.0      39578.0      37979.0      11736.0
# 11276     198855.0      72767.0      29318.0      30976.0      69554.0
# 11277      78908.0      39070.0      51841.0          NaN          NaN
# 11278      39070.0      78908.0      51841.0      69554.0          NaN
# 11279          NaN     198855.0      29318.0      92375.0      30976.0
#
#        AwayPlayer8  AwayPlayer9  AwayPlayer10  AwayPlayer11  TotalGoals  \
# 0          42594.0      38366.0      163670.0       75405.0           5
# 11276          NaN      39069.0       72633.0       30978.0           1
# 11277      30976.0      69554.0       68766.0       30978.0           5
# 11278      30976.0      43321.0       68766.0       30978.0           3
# 11279      69554.0      33436.0       72633.0       30978.0           5
#
#        HomeShoton  AwayShoton  HomeShotoff  AwayShotoff  HomeFoulCommit  \
# 0             NaN         NaN          NaN          NaN             NaN
# 11276         NaN         NaN          NaN          NaN             NaN
# 11277         NaN         NaN          NaN          NaN             NaN
# 11278         NaN         NaN          NaN          NaN             NaN
# 11279         NaN         NaN          NaN          NaN             NaN
#
#        AwayFoulCommit  HomeCard  AwayCard  HomeCross  AwayCross  HomeCorner  \
# 0                 NaN       NaN       NaN        NaN        NaN         NaN
# 11276             NaN       NaN       NaN        NaN        NaN         NaN
# 11277             NaN       NaN       NaN        NaN        NaN         NaN
# 11278             NaN       NaN       NaN        NaN        NaN         NaN
# 11279             NaN       NaN       NaN        NaN        NaN         NaN
#
#        AwayCorner  HomePossession  AwayPossession  HomeTeamID.1  \
# 0             NaN             NaN             NaN          8635
# 11276         NaN             NaN             NaN          2183
# 11277         NaN             NaN             NaN          8028
# 11278         NaN             NaN             NaN          8673
# 11279         NaN             NaN             NaN          2182
#
#       HomeTeamLongName HomeTeamShortName  HomeBuildUpPlaySpeed  \
# 0       RSC Anderlecht               AND                    50
# 11276      P. Warszawa               PWA                    30
# 11277    Piast Gliwice               PIG                    30
# 11278   Legia Warszawa               LEG                    30
# 11279      Lech Poznań               POZ                    40
#
#        HomeBuildUpPlayPassing  HomeChanceCreationPassing  \
# 0                          35                         70
# 11276                      40                         45
# 11277                      45                         45
# 11278                      35                         55
# 11279                      35                         45
#
#        HomeChanceCreationCrossing  HomeChanceCreationShooting  \
# 0                              50                          60
# 11276                          40                          70
# 11277                          35                          70
# 11278                          45                          70
# 11279                          40                          70
#
#        HomeDefencePressure  HomeDefenceAggression  HomeDefenceTeamWidth  \
# 0                       70                     50                    70
# 11276                   55                     65                    55
# 11277                   65                     70                    60
# 11278                   65                     70                    60
# 11279                   60                     55                    45
#
#        AwayTeamID.1 AwayTeamLongName AwayTeamShortName  AwayBuildUpPlaySpeed  \
# 0              8342   Club Brugge KV               CLB                    35
# 11276         10265     Wisła Kraków               WIS                    40
# 11277         10265     Wisła Kraków               WIS                    40
# 11278         10265     Wisła Kraków               WIS                    40
# 11279         10265     Wisła Kraków               WIS                    40
#
#        AwayBuildUpPlayPassing  AwayChanceCreationPassing  \
# 0                          40                         45
# 11276                      35                         55
# 11277                      35                         55
# 11278                      35                         55
# 11279                      35                         55
#
#        AwayChanceCreationCrossing  AwayChanceCreationShooting  \
# 0                              50                          45
# 11276                          35                          70
# 11277                          35                          70
# 11278                          35                          70
# 11279                          35                          70
#
#        AwayDefencePressure  AwayDefenceAggression  AwayDefenceTeamWidth
# 0                       60                     70                    70
# 11276                   70                     70                    65
# 11277                   70                     70                    65
# 11278                   70                     70                    65
# 11279                   70                     70                    65

# %%
df_merge.shape
# Out:
# (18243, 67)

# %%
df_merge.isna().sum()
# Out:
# Date                              0
# LeagueID                          0
# LeagueName                        0
# MatchID                           0
# HomeTeamID                        0
# AwayTeamID                        0
# HomeGoal                          0
# AwayGoal                          0
# HomePlayer1                     411
# HomePlayer2                     579
# HomePlayer3                     462
# HomePlayer4                     324
# HomePlayer5                     304
# HomePlayer6                     305
# HomePlayer7                     262
# HomePlayer8                     284
# HomePlayer9                     279
# HomePlayer10                    387
# HomePlayer11                    485
# AwayPlayer1                     273
# AwayPlayer2                     264
# AwayPlayer3                     320
# AwayPlayer4                     308
# AwayPlayer5                     320
# AwayPlayer6                     297
# AwayPlayer7                     272
# AwayPlayer8                     324
# AwayPlayer9                     313
# AwayPlayer10                    390
# AwayPlayer11                    483
# TotalGoals                        0
# HomeShoton                     7408
# AwayShoton                     7408
# HomeShotoff                    7408
# AwayShotoff                    7408
# HomeFoulCommit                 7408
# AwayFoulCommit                 7408
# HomeCard                       7408
# AwayCard                       7408
# HomeCross                      7408
# AwayCross                      7408
# HomeCorner                     7408
# AwayCorner                     7408
# HomePossession                12144
# AwayPossession                12144
# HomeTeamID.1                      0
# HomeTeamLongName                  0
# HomeTeamShortName                 0
# HomeBuildUpPlaySpeed              0
# HomeBuildUpPlayPassing            0
# HomeChanceCreationPassing         0
# HomeChanceCreationCrossing        0
# HomeChanceCreationShooting        0
# HomeDefencePressure               0
# HomeDefenceAggression             0
# HomeDefenceTeamWidth              0
# AwayTeamID.1                      0
# AwayTeamLongName                  0
# AwayTeamShortName                 0
# AwayBuildUpPlaySpeed              0
# AwayBuildUpPlayPassing            0
# AwayChanceCreationPassing         0
# AwayChanceCreationCrossing        0
# AwayChanceCreationShooting        0
# AwayDefencePressure               0
# AwayDefenceAggression             0
# AwayDefenceTeamWidth              0
# dtype: int64

# %%
player = "HomePlayer4"
date = "Date"
player_id = "PlayerID"
rating_column = "OverallRating"
left_dataframe = overall_rating
right_dataframe = df_merge


df_merge = overall_function(player, date, player_id, rating_column, left_dataframe, right_dataframe)

# %%
df_merge.sort_values("Date").head()
# Out:
#        Date  LeagueID              LeagueName  MatchID  HomeTeamID  \
# 0      2010         1  Belgium Jupiler League   665626        8635
# 11276  2010     15722      Poland Ekstraklasa   838608        2183
# 11277  2010     15722      Poland Ekstraklasa   674856        8028
# 11278  2010     15722      Poland Ekstraklasa   674870        8673
# 11279  2010     15722      Poland Ekstraklasa   838509        2182
#
#        AwayTeamID  HomeGoal  AwayGoal  HomePlayer1  HomePlayer2  HomePlayer3  \
# 0            8342         3         2         72.0         72.5         72.0
# 11276       10265         0         1         65.0         56.5         68.0
# 11277       10265         1         4          NaN          NaN         67.0
# 11278       10265         0         3         74.0         63.0          NaN
# 11279       10265         4         1         59.0         56.0         74.0
#
#        HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  HomePlayer8  \
# 0             74.0      38253.0      69713.0      38393.0     148302.0
# 11276          NaN      13551.0      69485.0      13449.0      74744.0
# 11277          NaN          NaN          NaN      13410.0          NaN
# 11278         67.0          NaN          NaN          NaN     112656.0
# 11279          NaN     114827.0      78413.0      39798.0      13428.0
#
#        HomePlayer9  HomePlayer10  HomePlayer11  AwayPlayer1  AwayPlayer2  \
# 0          38378.0       38383.0      181276.0      37990.0      36832.0
# 11276          NaN           NaN       69008.0      43313.0      72441.0
# 11277      69628.0      105535.0        4999.0          NaN          NaN
# 11278          NaN       69346.0           NaN          NaN          NaN
# 11279     138171.0       79747.0       79982.0      43313.0      72441.0
#
#        AwayPlayer3  AwayPlayer4  AwayPlayer5  AwayPlayer6  AwayPlayer7  \
# 0          21812.0      38336.0      39578.0      37979.0      11736.0
# 11276     198855.0      72767.0      29318.0      30976.0      69554.0
# 11277      78908.0      39070.0      51841.0          NaN          NaN
# 11278      39070.0      78908.0      51841.0      69554.0          NaN
# 11279          NaN     198855.0      29318.0      92375.0      30976.0
#
#        AwayPlayer8  AwayPlayer9  AwayPlayer10  AwayPlayer11  TotalGoals  \
# 0          42594.0      38366.0      163670.0       75405.0           5
# 11276          NaN      39069.0       72633.0       30978.0           1
# 11277      30976.0      69554.0       68766.0       30978.0           5
# 11278      30976.0      43321.0       68766.0       30978.0           3
# 11279      69554.0      33436.0       72633.0       30978.0           5
#
#        HomeShoton  AwayShoton  HomeShotoff  AwayShotoff  HomeFoulCommit  \
# 0             NaN         NaN          NaN          NaN             NaN
# 11276         NaN         NaN          NaN          NaN             NaN
# 11277         NaN         NaN          NaN          NaN             NaN
# 11278         NaN         NaN          NaN          NaN             NaN
# 11279         NaN         NaN          NaN          NaN             NaN
#
#        AwayFoulCommit  HomeCard  AwayCard  HomeCross  AwayCross  HomeCorner  \
# 0                 NaN       NaN       NaN        NaN        NaN         NaN
# 11276             NaN       NaN       NaN        NaN        NaN         NaN
# 11277             NaN       NaN       NaN        NaN        NaN         NaN
# 11278             NaN       NaN       NaN        NaN        NaN         NaN
# 11279             NaN       NaN       NaN        NaN        NaN         NaN
#
#        AwayCorner  HomePossession  AwayPossession  HomeTeamID.1  \
# 0             NaN             NaN             NaN          8635
# 11276         NaN             NaN             NaN          2183
# 11277         NaN             NaN             NaN          8028
# 11278         NaN             NaN             NaN          8673
# 11279         NaN             NaN             NaN          2182
#
#       HomeTeamLongName HomeTeamShortName  HomeBuildUpPlaySpeed  \
# 0       RSC Anderlecht               AND                    50
# 11276      P. Warszawa               PWA                    30
# 11277    Piast Gliwice               PIG                    30
# 11278   Legia Warszawa               LEG                    30
# 11279      Lech Poznań               POZ                    40
#
#        HomeBuildUpPlayPassing  HomeChanceCreationPassing  \
# 0                          35                         70
# 11276                      40                         45
# 11277                      45                         45
# 11278                      35                         55
# 11279                      35                         45
#
#        HomeChanceCreationCrossing  HomeChanceCreationShooting  \
# 0                              50                          60
# 11276                          40                          70
# 11277                          35                          70
# 11278                          45                          70
# 11279                          40                          70
#
#        HomeDefencePressure  HomeDefenceAggression  HomeDefenceTeamWidth  \
# 0                       70                     50                    70
# 11276                   55                     65                    55
# 11277                   65                     70                    60
# 11278                   65                     70                    60
# 11279                   60                     55                    45
#
#        AwayTeamID.1 AwayTeamLongName AwayTeamShortName  AwayBuildUpPlaySpeed  \
# 0              8342   Club Brugge KV               CLB                    35
# 11276         10265     Wisła Kraków               WIS                    40
# 11277         10265     Wisła Kraków               WIS                    40
# 11278         10265     Wisła Kraków               WIS                    40
# 11279         10265     Wisła Kraków               WIS                    40
#
#        AwayBuildUpPlayPassing  AwayChanceCreationPassing  \
# 0                          40                         45
# 11276                      35                         55
# 11277                      35                         55
# 11278                      35                         55
# 11279                      35                         55
#
#        AwayChanceCreationCrossing  AwayChanceCreationShooting  \
# 0                              50                          45
# 11276                          35                          70
# 11277                          35                          70
# 11278                          35                          70
# 11279                          35                          70
#
#        AwayDefencePressure  AwayDefenceAggression  AwayDefenceTeamWidth
# 0                       60                     70                    70
# 11276                   70                     70                    65
# 11277                   70                     70                    65
# 11278                   70                     70                    65
# 11279                   70                     70                    65

# %%
df_merge.shape
# Out:
# (18243, 67)

# %%
df_merge.isna().sum()
# Out:
# Date                              0
# LeagueID                          0
# LeagueName                        0
# MatchID                           0
# HomeTeamID                        0
# AwayTeamID                        0
# HomeGoal                          0
# AwayGoal                          0
# HomePlayer1                     411
# HomePlayer2                     579
# HomePlayer3                     462
# HomePlayer4                     539
# HomePlayer5                     304
# HomePlayer6                     305
# HomePlayer7                     262
# HomePlayer8                     284
# HomePlayer9                     279
# HomePlayer10                    387
# HomePlayer11                    485
# AwayPlayer1                     273
# AwayPlayer2                     264
# AwayPlayer3                     320
# AwayPlayer4                     308
# AwayPlayer5                     320
# AwayPlayer6                     297
# AwayPlayer7                     272
# AwayPlayer8                     324
# AwayPlayer9                     313
# AwayPlayer10                    390
# AwayPlayer11                    483
# TotalGoals                        0
# HomeShoton                     7408
# AwayShoton                     7408
# HomeShotoff                    7408
# AwayShotoff                    7408
# HomeFoulCommit                 7408
# AwayFoulCommit                 7408
# HomeCard                       7408
# AwayCard                       7408
# HomeCross                      7408
# AwayCross                      7408
# HomeCorner                     7408
# AwayCorner                     7408
# HomePossession                12144
# AwayPossession                12144
# HomeTeamID.1                      0
# HomeTeamLongName                  0
# HomeTeamShortName                 0
# HomeBuildUpPlaySpeed              0
# HomeBuildUpPlayPassing            0
# HomeChanceCreationPassing         0
# HomeChanceCreationCrossing        0
# HomeChanceCreationShooting        0
# HomeDefencePressure               0
# HomeDefenceAggression             0
# HomeDefenceTeamWidth              0
# AwayTeamID.1                      0
# AwayTeamLongName                  0
# AwayTeamShortName                 0
# AwayBuildUpPlaySpeed              0
# AwayBuildUpPlayPassing            0
# AwayChanceCreationPassing         0
# AwayChanceCreationCrossing        0
# AwayChanceCreationShooting        0
# AwayDefencePressure               0
# AwayDefenceAggression             0
# AwayDefenceTeamWidth              0
# dtype: int64

# %%
player = "HomePlayer5"
date = "Date"
player_id = "PlayerID"
rating_column = "OverallRating"
left_dataframe = overall_rating
right_dataframe = df_merge


df_merge = overall_function(player, date, player_id, rating_column, left_dataframe, right_dataframe)

# %%
df_merge.sort_values("Date").head()
# Out:
#        Date  LeagueID              LeagueName  MatchID  HomeTeamID  \
# 0      2010         1  Belgium Jupiler League   665626        8635
# 11276  2010     15722      Poland Ekstraklasa   838608        2183
# 11277  2010     15722      Poland Ekstraklasa   674856        8028
# 11278  2010     15722      Poland Ekstraklasa   674870        8673
# 11279  2010     15722      Poland Ekstraklasa   838509        2182
#
#        AwayTeamID  HomeGoal  AwayGoal  HomePlayer1  HomePlayer2  HomePlayer3  \
# 0            8342         3         2         72.0         72.5         72.0
# 11276       10265         0         1         65.0         56.5         68.0
# 11277       10265         1         4          NaN          NaN         67.0
# 11278       10265         0         3         74.0         63.0          NaN
# 11279       10265         4         1         59.0         56.0         74.0
#
#        HomePlayer4  HomePlayer5  HomePlayer6  HomePlayer7  HomePlayer8  \
# 0             74.0         70.5      69713.0      38393.0     148302.0
# 11276          NaN         60.5      69485.0      13449.0      74744.0
# 11277          NaN          NaN          NaN      13410.0          NaN
# 11278         67.0          NaN          NaN          NaN     112656.0
# 11279          NaN         57.0      78413.0      39798.0      13428.0
#
#        HomePlayer9  HomePlayer10  HomePlayer11  AwayPlayer1  AwayPlayer2  \
# 0          38378.0       38383.0      181276.0      37990.0      36832.0
# 11276          NaN           NaN       69008.0      43313.0      72441.0
# 11277      69628.0      105535.0        4999.0          NaN          NaN
# 11278          NaN       69346.0           NaN          NaN          NaN
# 11279     138171.0       79747.0       79982.0      43313.0      72441.0
#
#        AwayPlayer3  AwayPlayer4  AwayPlayer5  AwayPlayer6  AwayPlayer7  \
# 0          21812.0      38336.0      39578.0      37979.0      11736.0
# 11276     198855.0      72767.0      29318.0      30976.0      69554.0
# 11277      78908.0      39070.0      51841.0          NaN          NaN
# 11278      39070.0      78908.0      51841.0      69554.0          NaN
# 11279          NaN     198855.0      29318.0      92375.0      30976.0
#
#        AwayPlayer8  AwayPlayer9  AwayPlayer10  AwayPlayer11  TotalGoals  \
# 0          42594.0      38366.0      163670.0       75405.0           5
# 11276          NaN      39069.0       72633.0       30978.0           1
# 11277      30976.0      69554.0       68766.0       30978.0           5
# 11278      30976.0      43321.0       68766.0       30978.0           3
# 11279      69554.0      33436.0       72633.0       30978.0           5
#
#        HomeShoton  AwayShoton  HomeShotoff  AwayShotoff  HomeFoulCommit  \
# 0             NaN         NaN          NaN          NaN             NaN
# 11276         NaN         NaN          NaN          NaN             NaN
# 11277         NaN         NaN          NaN          NaN             NaN
# 11278         NaN         NaN          NaN          NaN             NaN
# 11279         NaN         NaN          NaN          NaN             NaN
#
#        AwayFoulCommit  HomeCard  AwayCard  HomeCross  AwayCross  HomeCorner  \
# 0                 NaN       NaN       NaN        NaN        NaN         NaN
# 11276             NaN       NaN       NaN        NaN        NaN         NaN
# 11277             NaN       NaN       NaN        NaN        NaN         NaN
# 11278             NaN       NaN       NaN        NaN        NaN         NaN
# 11279             NaN       NaN       NaN        NaN        NaN         NaN
#
#        AwayCorner  HomePossession  AwayPossession  HomeTeamID.1  \
# 0             NaN             NaN             NaN          8635
# 11276         NaN             NaN             NaN          2183
# 11277         NaN             NaN             NaN          8028
# 11278         NaN             NaN             NaN          8673
# 11279         NaN             NaN             NaN          2182
#
#       HomeTeamLongName HomeTeamShortName  HomeBuildUpPlaySpeed  \
# 0       RSC Anderlecht               AND                    50
# 11276      P. Warszawa               PWA                    30
# 11277    Piast Gliwice               PIG                    30
# 11278   Legia Warszawa               LEG                    30
# 11279      Lech Poznań               POZ                    40
#
#        HomeBuildUpPlayPassing  HomeChanceCreationPassing  \
# 0                          35                         70
# 11276                      40                         45
# 11277                      45                         45
# 11278                      35                         55
# 11279                      35                         45
#
#        HomeChanceCreationCrossing  HomeChanceCreationShooting  \
# 0                              50                          60
# 11276                          40                          70
# 11277                          35                          70
# 11278                          45                          70
# 11279                          40                          70
#
#        HomeDefencePressure  HomeDefenceAggression  HomeDefenceTeamWidth  \
# 0                       70                     50                    70
# 11276                   55                     65                    55
# 11277                   65                     70                    60
# 11278                   65                     70                    60
# 11279                   60                     55                    45
#
#        AwayTeamID.1 AwayTeamLongName AwayTeamShortName  AwayBuildUpPlaySpeed  \
# 0              8342   Club Brugge KV               CLB                    35
# 11276         10265     Wisła Kraków               WIS                    40
# 11277         10265     Wisła Kraków               WIS                    40
# 11278         10265     Wisła Kraków               WIS                    40
# 11279         10265     Wisła Kraków               WIS                    40
#
#        AwayBuildUpPlayPassing  AwayChanceCreationPassing  \
# 0                          40                         45
# 11276                      35                         55
# 11277                      35                         55
# 11278                      35                         55
# 11279                      35                         55
#
#        AwayChanceCreationCrossing  AwayChanceCreationShooting  \
# 0                              50                          45
# 11276                          35                          70
# 11277                          35                          70
# 11278                          35                          70
# 11279                          35                          70
#
#        AwayDefencePressure  AwayDefenceAggression  AwayDefenceTeamWidth
# 0                       60                     70                    70
# 11276                   70                     70                    65
# 11277                   70                     70                    65
# 11278                   70                     70                    65
# 11279                   70                     70                    65

# %%
df_merge.shape
# Out:
# (18243, 67)

# %%
df_merge.isna().sum()
# Out:
# Date                              0
# LeagueID                          0
# LeagueName                        0
# MatchID                           0
# HomeTeamID                        0
# AwayTeamID                        0
# HomeGoal                          0
# AwayGoal                          0
# HomePlayer1                     411
# HomePlayer2                     579
# HomePlayer3                     462
# HomePlayer4                     539
# HomePlayer5                     478
# HomePlayer6                     305
# HomePlayer7                     262
# HomePlayer8                     284
# HomePlayer9                     279
# HomePlayer10                    387
# HomePlayer11                    485
# AwayPlayer1                     273
# AwayPlayer2                     264
# AwayPlayer3                     320
# AwayPlayer4                     308
# AwayPlayer5                     320
# AwayPlayer6                     297
# AwayPlayer7                     272
# AwayPlayer8                     324
# AwayPlayer9                     313
# AwayPlayer10                    390
# AwayPlayer11                    483
# TotalGoals                        0
# HomeShoton                     7408
# AwayShoton                     7408
# HomeShotoff                    7408
# AwayShotoff                    7408
# HomeFoulCommit                 7408
# AwayFoulCommit                 7408
# HomeCard                       7408
# AwayCard                       7408
# HomeCross                      7408
# AwayCross                      7408
# HomeCorner                     7408
# AwayCorner                     7408
# HomePossession                12144
# AwayPossession                12144
# HomeTeamID.1                      0
# HomeTeamLongName                  0
# HomeTeamShortName                 0
# HomeBuildUpPlaySpeed              0
# HomeBuildUpPlayPassing            0
# HomeChanceCreationPassing         0
# HomeChanceCreationCrossing        0
# HomeChanceCreationShooting        0
# HomeDefencePressure               0
# HomeDefenceAggression             0
# HomeDefenceTeamWidth              0
# AwayTeamID.1                      0
# AwayTeamLongName                  0
# AwayTeamShortName                 0
# AwayBuildUpPlaySpeed              0
# AwayBuildUpPlayPassing            0
# AwayChanceCreationPassing         0
# AwayChanceCreationCrossing        0
# AwayChanceCreationShooting        0
# AwayDefencePressure               0
# AwayDefenceAggression             0
# AwayDefenceTeamWidth              0
# dtype: int64
