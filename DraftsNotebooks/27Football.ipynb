# %% [markdown]
# ## Display Features

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings

from xml.etree.ElementTree import fromstring, ElementTree
import xml.etree.ElementTree as ET

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

# %% [markdown]
# # Matches

# %%
matches = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches7.csv",
    index_col=0,
)

# %% [markdown]
# # Moving Result to the End

# %%
result = matches.pop('Result')
matches.insert(63, 'Result', result)

# %% [markdown]
# # Changing Result Values

# %%
matches['Result'] = matches['Result'].replace(1, 'Home Win')
matches['Result'] = matches['Result'].replace(-1, 'Away Win')
matches['Result'] = matches['Result'].replace(0, 'Draw')

# %%
matches.to_csv("C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches8.csv",
)

# %%
matches = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\matches8.csv",
    index_col=0,
)

# %%
matches.head()
# Out:
#    Date  LeagueID              LeagueName  MatchID  HomeTeamID  \
# 0  2010         1  Belgium Jupiler League   665626        8635
# 1  2010         1  Belgium Jupiler League   838635        8635
# 2  2010         1  Belgium Jupiler League   838544        9986
# 3  2010         1  Belgium Jupiler League   838714        8203
# 4  2010         1  Belgium Jupiler League   665737        9997
#
#      HomeTeamLongName HomeTeamShortName  AwayTeamID AwayTeamLongName  \
# 0      RSC Anderlecht               AND        8342   Club Brugge KV
# 1      RSC Anderlecht               AND        8342   Club Brugge KV
# 2  Sporting Charleroi               CHA        8342   Club Brugge KV
# 3         KV Mechelen               MEC        8342   Club Brugge KV
# 4   Sint-Truidense VV               STT        8342   Club Brugge KV
#
#   AwayTeamShortName  HomeGoal  AwayGoal  TotalGoals  HomePlayer1  HomePlayer2  \
# 0               CLB         3         2           5         72.0         72.0
# ...

# %%
sns.countplot(x="HomeGoal", data=matches)
# Out:
# <AxesSubplot: xlabel='HomeGoal', ylabel='count'>

# %%
sns.countplot(x="AwayGoal", data=matches)
# Out:
# <AxesSubplot: xlabel='AwayGoal', ylabel='count'>

# %%
sns.countplot(x="TotalGoals", data=matches);

# %%
goals_season = matches[["Date","TotalGoals","HomeGoal","AwayGoal"]].groupby(by="Date").sum()

# %%
sns.lineplot(data=goals_season)
plt.xticks(rotation = 60)


new_labels = ['Total Goals',"Away Goals","Home Goals"]
plt.ylabel("Number of Goals")
plt.xlabel("Season")
plt.legend(labels=new_labels)
plt.show()

plt.show()
