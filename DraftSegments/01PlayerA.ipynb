# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

# %% [markdown]
# # Load Dataset

# %%
connection = sqlite3.connect(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSet\\database.sqlite"
)

# %%
player = pd.read_sql("""
                          SELECT * 
                          FROM Player
                          """, connection)

player.head()
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  \
# 0   1         505942  Aaron Appindangoye              218353
# 1   2         155782     Aaron Cresswell              189615
# 2   3         162549         Aaron Doran              186170
# 3   4          30572       Aaron Galindo              140161
# 4   5          23780        Aaron Hughes               17725
#
#               Birthday  Height  weight
# 0  1992-02-29 00:00:00  182.88     187
# 1  1989-12-15 00:00:00  170.18     146
# 2  1991-05-13 00:00:00  170.18     163
# 3  1982-05-08 00:00:00  182.88     198
# 4  1979-11-08 00:00:00  182.88     154

# %%
player187 = pd.read_sql("""
                          SELECT *
                          FROM player
                          GROUP BY player_name, height, weight
                          """, connection)

player187.head(100)
# Out:
#      id  player_api_id                player_name  player_fifa_api_id  \
# 0     1         505942         Aaron Appindangoye              218353
# 1     2         155782            Aaron Cresswell              189615
# 2     3         162549                Aaron Doran              186170
# 3     4          30572              Aaron Galindo              140161
# 4     5          23780               Aaron Hughes               17725
# 5     6          27316                 Aaron Hunt              158138
# 6     7         564793                 Aaron Kuhl              221280
# 7     8          30895               Aaron Lennon              152747
# 8     9         528212               Aaron Lennox              206592
# 9    10         101042              Aaron Meijers              188621
# 10   11          23889              Aaron Mokoena               47189
# 11   12         231592                 Aaron Mooy              194958
# ...

# %%
                             WHERE QuestionID = 1 
                             AND age >= 15 
                             AND age <= 70

# %%
player_weight = pd.read_sql("""
                          SELECT *
                          FROM player
                          ALTER TABLE player RENAME weight to Weight;
                          """, connection)

player_weight.head(100)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:2019, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2018 try:
# -> 2019     cur.execute(*args, **kwargs)
#    2020     return cur
#
# OperationalError: near "ALTER": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 player_weight = pd.read_sql("""
#       2                           SELECT *
#       3                           FROM player
#       4                           ALTER TABLE player RENAME weight to Weight;
#       5                           """, connection)
#       7 player_weight.head(100)
#
# ...
