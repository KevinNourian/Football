# %% [markdown]
# # Analysis of Data Related to European Football

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings

from xml.etree.ElementTree import fromstring, ElementTree
import xml.etree.ElementTree as ET

# %% [markdown]
# # Display Parameters

# %% [markdown]
# ## Display Features

# %%
# %matplotlib inline
pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Colors

# %%
color_1 = "bisque"
color_2 = "crimson"
color_3 = "orangered"
color_4 = "lightcoral"
color_5 = "royalblue"
color_6 = "pink"
color_7 = "indianred"
color_8 = "slategrey"
color_9 = "salmon"
color_10 = "beige"
color_11 = "coral"
color_13 = "grey"
color_14 = "tan"
color_15 = "wheat"
color_16 = "tomato"

# %% [markdown]
# ## Figure Parameters

# %%
size = 20

params = {
    "font.family": "Times New Roman",
    "font.size": size,
    "axes.labelsize": size,
    "xtick.labelsize": size * 0.75,
    "ytick.labelsize": size * 0.75,
    "figure.titlesize": size * 1.5,
    "axes.titlesize": size * 1.5,
    "axes.titlepad": size,
    "axes.labelpad": size - 10,
    "lines.linewidth": 2,
    "axes.spines.top": False,
    "axes.spines.right": False,
    "axes.spines.left": False,
    "axes.spines.bottom": False,
    "legend.fontsize": size,
}

# %% [markdown]
# # Players

# %%
players = pd.read_csv(
    "C:\\Users\\Space\\Documents\\py\\Projects\\TuringCollege\\Football\\DataSets\\players3.csv",
    index_col=0,
)

# %%
players.head()
# Out:
#    PlayerID  Date PreferredFoot AttackWorkRate DefenceWorkRate  Birthday  \
# 0      2625  2007         right           high          medium    1981.0
# 1      2625  2008         right           high          medium    1981.0
# 2      2625  2010         right           high          medium    1981.0
# 3      2625  2011         right           high          medium    1981.0
# 4      2625  2012         right         medium          medium    1981.0
#
#    Height  Weight    BMI  OverallRating  Potential  Crossing  Finishing  \
# 0  175.26   154.0  22.74           63.0       64.0      48.0       48.0
# 1  175.26   154.0  22.74           60.0       64.0      48.0       48.0
# 2  175.26   154.0  22.74           60.0       64.0      48.0       48.0
# 3  175.26   154.0  22.74           58.5       60.5      52.0       47.0
# 4  175.26   154.0  22.74           58.0       58.0      52.0       47.0
#
#    HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FreeKickAccuracy  \
# ...

# %%
players.shape
# Out:
# (71615, 40)

# %%
round(players.describe(), 2)
# Out:
#         PlayerID     Date  Birthday    Height    Weight       BMI  \
# count   71615.00  71615.0  71615.00  71615.00  71615.00  71615.00
# mean   128408.91   2011.4   1986.35    182.00    169.03     23.12
# std    134076.98      2.9      4.90      6.39     15.05      1.32
# min      2625.00   2007.0   1969.00    157.48    117.00     17.87
# 25%     33881.00   2009.0   1983.00    177.80    159.00     22.20
# 50%     69803.00   2012.0   1987.00    182.88    168.00     23.10
# 75%    182075.00   2014.0   1990.00    185.42    179.00     23.98
# max    750584.00   2016.0   1999.00    208.28    243.00     30.86
#
#        OverallRating  Potential  Crossing  Finishing  HeadingAccuracy  \
# count       71615.00   71615.00  71615.00   71615.00         71615.00
# mean           67.26      72.78     53.31      48.11            56.18
# std             7.34       6.72     17.36      19.15            16.80
# min            33.00      39.00      2.00       2.00             3.00
# ...

# %%
players.size
# Out:
# 2864600

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71615 entries, 0 to 71614
# Data columns (total 40 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PlayerID          71615 non-null  int64
#  1   Date              71615 non-null  int64
#  2   PreferredFoot     71615 non-null  object
#  3   AttackWorkRate    71615 non-null  object
#  4   DefenceWorkRate   71615 non-null  object
#  5   Birthday          71615 non-null  float64
#  6   Height            71615 non-null  float64
#  7   Weight            71615 non-null  float64
#  8   BMI               71615 non-null  float64
#  9   OverallRating     71615 non-null  float64
#  10  Potential         71615 non-null  float64
#  11  Crossing          71615 non-null  float64
#  12  Finishing         71615 non-null  float64
#  13  HeadingAccuracy   71615 non-null  float64
#  14  ShortPassing      71615 non-null  float64
#  15  Volleys           71615 non-null  float64
# ...

# %%
players.sample(15)
# Out:
#        PlayerID  Date PreferredFoot AttackWorkRate DefenceWorkRate  Birthday  \
# 56497    196203  2015          left         medium          medium    1990.0
# 663       10950  2010          left         medium          medium    1980.0
# 31386     42852  2009          left         medium          medium    1986.0
# 4675      23947  2013          left         medium            high    1986.0
# 20654     36774  2013         right           high          medium    1987.0
# 69589    503149  2007         right         medium          medium    1993.0
# 27954     40676  2013         right         medium          medium    1984.0
# 14641     31047  2013         right         medium          medium    1985.0
# 41500    106175  2007          left         medium          medium    1986.0
# 55107    187336  2016          left         medium            high    1990.0
# 50755    167065  2015         right           high          medium    1990.0
# ...

# %%
players['PreferredFoot'].value_counts()
# Out:
# right    53969
# left     17646
# Name: PreferredFoot, dtype: int64

# %%
players['Birthday'].value_counts().sort_values()
# Out:
# 1999.0       6
# 1969.0      12
# 1970.0      29
# 1971.0      57
# 1998.0      61
# 1972.0      62
# 1973.0     141
# 1974.0     263
# 1997.0     321
# 1975.0     456
# 1976.0     748
# 1996.0     834
# 1977.0    1017
# 1995.0    1330
# 1978.0    1552
# 1994.0    2145
# 1979.0    2264
# 1993.0    2713
# 1980.0    2864
# 1981.0    3383
# 1982.0    3499
# 1992.0    3694
# 1983.0    4090
# 1991.0    4460
# 1985.0    4530
# 1984.0    4574
# 1990.0    4681
# 1989.0    5172
# 1987.0    5343
# 1986.0    5367
# 1988.0    5947
# Name: Birthday, dtype: int64

# %%
binnedPopulation = (pd.cut(players['Birthday'], 20))
binnedPopulation.value_counts()
# Out:
# (1985.5, 1987.0]     10710
# (1988.5, 1990.0]      9853
# (1982.5, 1984.0]      8664
# (1991.5, 1993.0]      6407
# (1979.5, 1981.0]      6247
# (1987.0, 1988.5]      5947
# (1984.0, 1985.5]      4530
# (1990.0, 1991.5]      4460
# (1981.0, 1982.5]      3499
# (1976.5, 1978.0]      2569
# (1978.0, 1979.5]      2264
# (1994.5, 1996.0]      2164
# (1993.0, 1994.5]      2145
# (1975.0, 1976.5]       748
# (1973.5, 1975.0]       719
# (1996.0, 1997.5]       321
# (1972.0, 1973.5]       141
# (1970.5, 1972.0]       119
# (1997.5, 1999.0]        67
# (1968.97, 1970.5]       41
# Name: Birthday, dtype: int64

# %%
sns.countplot(data=players,x='PreferredFoot')
# Out:
# <AxesSubplot: xlabel='PreferredFoot', ylabel='count'>

# %%
players['AttackWorkRate'].value_counts()
# Out:
# medium    50394
# high      14719
# low        3570
# None       1853
# []          674
# norm        227
# y            61
# stoc         60
# le           57
# Name: AttackWorkRate, dtype: int64

# %%
allowed_values = ['high', 'medium', 'low', 'None']
players.loc[~players["AttackWorkRate"].isin(allowed_values), "AttackWorkRate"] = "None"

# %%
players['AttackWorkRate'].value_counts()
# Out:
# medium    50394
# high      14719
# low        3570
# None       2932
# Name: AttackWorkRate, dtype: int64

# %%
sns.countplot(data=players,x='AttackWorkRate')
# Out:
# <AxesSubplot: xlabel='AttackWorkRate', ylabel='count'>

# %%
players.loc[~players["DefenceWorkRate"].isin(allowed_values), "DefenceWorkRate"] = "None"
players['DefenceWorkRate'].value_counts()
# Out:
# medium    51851
# high       9721
# low        7048
# None       2995
# Name: DefenceWorkRate, dtype: int64

# %%
sns.countplot(data=players,x='DefenceWorkRate')
# Out:
# <AxesSubplot: xlabel='DefenceWorkRate', ylabel='count'>

# %%
plt.figure(dpi = 200)
sns.boxplot(x='Birthday',y='OverallRating',data=players)
# Out:
# <AxesSubplot: xlabel='Birthday', ylabel='OverallRating'>

# %%
age = players['Birthday'].value_counts(bins = 10, sort = False)

# %%
age
# Out:
# (1968.969, 1972.0]      160
# (1972.0, 1975.0]        860
# (1975.0, 1978.0]       3317
# (1978.0, 1981.0]       8511
# (1981.0, 1984.0]      12163
# (1984.0, 1987.0]      15240
# (1987.0, 1990.0]      15800
# (1990.0, 1993.0]      10867
# (1993.0, 1996.0]       4309
# (1996.0, 1999.0]        388
# Name: Birthday, dtype: int64

# %%
plt.figure(dpi = 200)
sns.boxplot(x='Birthday',y='OverallRating',data=players)

# %%
sns.countplot(data=age,x='DefenceWorkRate')
